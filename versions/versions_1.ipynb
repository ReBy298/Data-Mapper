# %% [markdown]
#                                             DATA MAPPER

# %% [markdown]
# 1st Version -
#
# -> Tackling how to convert categorical data to numerical so algorithm understands it,
#
# -> find the algorithm which helps in storing data in numerical form without loosing the meaning of the
# sentence.
#
# -> Utilize cosine similarity to get the matches from LHS to RHS.
#
# -> methods to visualize results

# %%
# !pip install torch
# !pip install sentence-transformers
# !pip install pandas
# !pip install matplotlib
# !pip install --upgrade transformers sentence-transformers
# Out:
# Requirement already satisfied: torch in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (2.5.1)
# Requirement already satisfied: filelock in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from jinja2->torch) (3.0.2)
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: sentence-transformers in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (3.4.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from sentence-transformers) (4.48.2)
# Requirement already satisfied: tqdm in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from sentence-transformers) (4.67.0)
# Requirement already satisfied: torch>=1.11.0 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from sentence-transformers) (2.5.1)
# Requirement already satisfied: scikit-learn in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from sentence-transformers) (1.5.2)
# Requirement already satisfied: scipy in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from sentence-transformers) (1.14.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from sentence-transformers) (0.26.2)
# Requirement already satisfied: Pillow in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from sentence-transformers) (11.0.0)
# Requirement already satisfied: filelock in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: networkx in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: numpy>=1.17 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.8.30)
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: pandas in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from matplotlib) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: transformers in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (4.48.2)
# Requirement already satisfied: sentence-transformers in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (3.4.1)
# Requirement already satisfied: filelock in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.24.0 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from transformers) (0.26.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from transformers) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from transformers) (4.67.0)
# Requirement already satisfied: torch>=1.11.0 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from sentence-transformers) (2.5.1)
# Requirement already satisfied: scikit-learn in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from sentence-transformers) (1.5.2)
# Requirement already satisfied: scipy in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from sentence-transformers) (1.14.1)
# Requirement already satisfied: Pillow in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from sentence-transformers) (11.0.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (2024.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.24.0->transformers) (4.12.2)
# Requirement already satisfied: networkx in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer, util
import numpy as np

# %%
#Load csv files
df1 = pd.read_csv(r"C:\Users\Yasvanth.Pamidi\OneDrive - ENCORA\Desktop\DataMap\metadata files\LHS.csv") #path to file1
df2 = pd.read_csv(r"C:\Users\Yasvanth.Pamidi\OneDrive - ENCORA\Desktop\DataMap\metadata files\RHS.csv") #path to file2
#df1 = pd.read_csv("./LHS 2.csv") #path to file1
#df2 = pd.read_csv("./RHS 3.csv") #path to file2

#define columns to compare by converting columns in to string format

column1 = 'Description' #column name in df1
df1[column1] = df1[column1].astype(str)

column2 = 'Description' #column name in df2
df2[column2] = df2[column2].astype(str)

# %%
# Load a pre-trained model
model = SentenceTransformer('sentence-transformers/paraphrase-mpnet-base-v2')

# %%
#Generate Embeddings for each sentense in the selected columns

embeddings1 = model.encode(df1[column1].to_list(), show_progress_bar=True,convert_to_tensor=True)
embeddings2 = model.encode(df2[column2].to_list(), show_progress_bar=True,convert_to_tensor=True)
# Out:
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/15 [00:00<?, ?it/s]

# %%
#compute the cosine_similarity_matrix

similarity_matrix = util.cos_sim(embeddings1,embeddings2).cpu().numpy()

# %%
# Select a specific sentence from embeddings1, e.g., the first sentence (index 0)
selected_index = 128
similarities = similarity_matrix[selected_index]  # Get similarity scores for the selected sentence

# Find the indices of the top 3 most similar sentences in embeddings2
top_3_indices = np.argsort(similarities)[-3:][::-1]  # Sort and get indices in descending order

#print the actual sentence
print('Actual Sentence: '+df1[column1][selected_index])

# Print the top 3 indices and their similarity scores
for idx in top_3_indices:
    print(f"Sentence index in embeddings2: {idx}, Similarity: {similarities[idx]}")

# Example: If you want to retrieve the actual sentences, ensure you have access to the original sentences.
# embeddings2_sentences is assumed to be the list of sentences corresponding to embeddings2
top_3_sentences = [df2[column2][idx] for idx in top_3_indices]
print("Top 3 most similar sentences:", top_3_sentences)
# Out:
# Actual Sentence: Assortment List Type
# Sentence index in embeddings2: 83, Similarity: 0.39559268951416016
# Sentence index in embeddings2: 259, Similarity: 0.3921678066253662
# Sentence index in embeddings2: 2, Similarity: 0.3866002857685089
# Top 3 most similar sentences: ['Denotes the type of the product.\nValues:\n1. FPS\n2. FPC \n3. OG\n4. OO \n5. Item Only\n6. Shipper \n7. Ingredient ', 'Category in which the item is picked & grouped into Totes by Penske . Also used by stores to determine what is in the totes so that they can go to the correct location in store', 'Variety of item, as defined by the MCoE at sub-category level. Attribute managed by MCoE']

# %%
import json

# Function to retrieve top-N most similar sentences for all sentences in embeddings1
def retrieve_top_similar_sentences_json(num_sentences, top_n):
    results = []  # List to hold all results

    for selected_index in range(num_sentences):
        # Get similarity scores for the selected sentence
        similarities = similarity_matrix[selected_index]

        # Find the indices of the top N most similar sentences in embeddings2
        top_indices = np.argsort(similarities)[-top_n:][::-1]  # Sort in descending order

        # Construct matches
        matches = []
        for rank, idx in enumerate(top_indices, start=1):
            matches.append({
                f"rhs_field_desc_{rank}": df2[column2][idx],
                "rhs_field_score": float(similarities[idx])  # Convert to native Python float
            })

        # Construct the result for the current LHS sentence
        result = {
          #  f"lhs_field_{selected_index}": df1[column1][selected_index],
            f"lhs_desc_{selected_index}": df1[column1][selected_index],
            "matches": matches
        }

        # Append to results
        results.append(result)

    # Format as JSON
    final_output = {"results": results}
    return final_output

# User inputs: number of sentences to process and top-N similarities to retrieve
num_sentences_to_process = int(input("Enter the number of sentences from LHS to process: ") or len(df1))
top_n = int(input("Enter the number of top similar sentences to retrieve (N): ") or 3)

# Retrieve results in the specified JSON format
output_json = retrieve_top_similar_sentences_json(num_sentences_to_process, top_n)

# Print the output as formatted JSON
print(json.dumps(output_json, indent=2))
# Out:
# {
#   "results": [
#     {
#       "lhs_desc_0": "Client",
#       "matches": [
#         {
#           "rhs_field_desc_1": "short name of the option set ; customer facing",
#           "rhs_field_score": 0.44968175888061523
#         },
#         {
#           "rhs_field_desc_2": "identifies if the product is offered thru Web, Catering lite , retil etc",
#           "rhs_field_score": 0.35248929262161255
#         },
#         {
#           "rhs_field_desc_3": "The WAWA employee email acting as the primary contact for the item",
#           "rhs_field_score": 0.3440648913383484
#         },
#         {
#           "rhs_field_desc_4": "Indicates if PD review  is requied for this item ",
#           "rhs_field_score": 0.33600735664367676
#         }
#       ]
#     },
#     {
#       "lhs_desc_1": "Material Number",
#       "matches": [
#         {
#           "rhs_field_desc_1": "Equipment model number from the manufacturer",
#           "rhs_field_score": 0.560577392578125
#         },
#         {
#           "rhs_field_desc_2": "The quantity of each component item in a shipper display",
#           "rhs_field_score": 0.5381794571876526
#         },
#         {
#           "rhs_field_desc_3": "Number of tiers the pallets are stacked into",
#           "rhs_field_score": 0.48817726969718933
#         },
#         {
#           "rhs_field_desc_4": "The Net  weight of the package",
#           "rhs_field_score": 0.47326576709747314
#         }
#       ]
#     },
#     {
#       "lhs_desc_2": "Created On",
#       "matches": [
#         {
#           "rhs_field_desc_1": "upload letter of guarantee ",
#           "rhs_field_score": 0.3384504020214081
#         },
#         {
#           "rhs_field_desc_2": "System generated unique Id for a option set",
#           "rhs_field_score": 0.33561018109321594
#         },
#         {
#           "rhs_field_desc_3": "Effective Start date",
#           "rhs_field_score": 0.32464995980262756
#         },
#         {
#           "rhs_field_desc_4": "Effective Start date",
#           "rhs_field_score": 0.32464995980262756
#         }
#       ]
#     },
#     {
#       "lhs_desc_3": "Name of Person who Created the Object",
#       "matches": [
#         {
#           "rhs_field_desc_1": "name of the item as represented by the seller / vendor",
#           "rhs_field_score": 0.41159123182296753
#         },
#         {
#           "rhs_field_desc_2": "Brand name of product",
#           "rhs_field_score": 0.33951500058174133
#         },
#         {
#           "rhs_field_desc_3": "Logo for the product",
#           "rhs_field_score": 0.3229120969772339
#         },
#         {
#           "rhs_field_desc_4": "A design, symbol or series of words that identifies the brand.",
#           "rhs_field_score": 0.3133503496646881
#         }
#       ]
#     },
#     {
#       "lhs_desc_4": "Date of Last Change",
#       "matches": [
#         {
#           "rhs_field_desc_1": "Effective End  date",
#           "rhs_field_score": 0.6233363151550293
#         },
#         {
#           "rhs_field_desc_2": "Effective Start date ; every time we changes the date, the latest start date will be captured (SCD-1)",
#           "rhs_field_score": 0.516474187374115
#         },
#         {
#           "rhs_field_desc_3": "Effective Start date",
#           "rhs_field_score": 0.5051547884941101
#         },
#         {
#           "rhs_field_desc_4": "Effective Start date",
#           "rhs_field_score": 0.5051547884941101
#         }
#       ]
#     }
#   ]
# }

# %% [markdown]
#                                                         version 2

# %% [markdown]
# Version 2:
#
# -> Added sample datatype check on top of similarity score.
#
# -> Enhanced the model
#
# -> Added new representation with more information

# %%
# !pip install tqdm
# !pip install ipywidgets
# Out:
# Requirement already satisfied: tqdm in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (4.67.0)
# Requirement already satisfied: colorama in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from tqdm) (0.4.6)
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: ipywidgets in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (8.1.5)
# Requirement already satisfied: comm>=0.1.3 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from ipywidgets) (8.29.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from ipywidgets) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from ipywidgets) (3.0.13)
# Requirement already satisfied: decorator in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (4.12.2)
# Requirement already satisfied: colorama in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\yasvanth.pamidi\onedrive - encora\desktop\vsc\datamapper\.venv\lib\site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import torch
from tqdm import tqdm

# %%
#function to encode sentences in batches
def batch_encode(column, batch_size, model):
    embeddings = []
    column = column.tolist()
    with torch.no_grad():
        for i in tqdm(range(0, len(column), batch_size), desc = "Encoding Batches"):
            batch = column[i:i+batch_size]
            batch_embeddings = model.encode(batch, convert_to_tensor= True,show_progress_bar=True)
            embeddings.append(batch_embeddings)
    return torch.cat(embeddings, dim=0)


embeddings1 = batch_encode(df1[column1], batch_size=128, model=model)
embeddings2 = batch_encode(df2[column2], batch_size=128, model=model)
# Out:
# Encoding Batches:   0%|          | 0/2 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding Batches:  50%|█████     | 1/2 [00:01<00:01,  1.00s/it]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding Batches: 100%|██████████| 2/2 [00:01<00:00,  1.02it/s]
# Encoding Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding Batches:  25%|██▌       | 1/4 [00:02<00:07,  2.66s/it]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding Batches:  50%|█████     | 2/4 [00:05<00:05,  2.73s/it]
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]
# Encoding Batches:  75%|███████▌  | 3/4 [00:07<00:02,  2.47s/it]
# Batches:   0%|          | 0/3 [00:00<?, ?it/s]
# Encoding Batches: 100%|██████████| 4/4 [00:09<00:00,  2.28s/it]

# %%
#compute the cosine_similarity_matrix here output will be in range of -1 to 1

similarity_matrix = util.cos_sim(embeddings1,embeddings2).cpu().numpy()

# %%
# normalizing the similarity matrix as the out values to range from 0 to 1 
normalized_similarity_matrix = (similarity_matrix + 1) / 2

# %%
# To verify the Data Types as we have data belonging to different databases 


type_mapping = {
    "CHAR": ["VARCHAR"],
    "NUMC": ["INTEGER", "BIGINT", "NUMERIC"],
    "DATS": ["DATE"],
    "TIMS": ["TIME"],
    "DEC": ["NUMERIC", "FLOAT"],
    "INT4": ["INTEGER", "BIGINT"]
}

# %% [markdown]
# ONE TO MANY - Below code gets the topN similarities from RHS for particular index on LHS and shows if data types are compatible or not

# %%
import json
import numpy as np
import pandas as pd

# Function to retrieve top-N most similar sentences with data type validation
def retrieve_top_similar_sentences_json(selected_index, top_n, similarity_matrix, df1, df2, column1, column2, type_mapping):
    # Initialize variables
    similarities = similarity_matrix[selected_index]
    top_indices = np.argsort(similarities)[-top_n:][::-1]  # Top-N indices sorted in descending order
    
    lhs_field = df1.loc[selected_index, 'Field Name']  # LHS field name
    lhs_desc = df1.loc[selected_index, column1]        # LHS description
    lhs_type = df1.loc[selected_index, 'Data_Type']    # LHS data type
    
    # List to store all matches
    matches = [
        {
            "rank": rank + 1,
            "rhs_field_score": float(similarities[idx]),
            "rhs_index": int(df2.index[idx]),
            "rhs_field_name": df2.loc[idx, 'Attribute'],   # RHS attribute name
            "rhs_field_desc": df2.loc[idx, column2],       # RHS description
            "rhs_data_type": df2.loc[idx, 'Data_Type'],    # RHS data type
            "compatibility": "Compatible" if df2.loc[idx, 'Data_Type'] in type_mapping.get(lhs_type, []) else "Incompatible"
        }
        for rank, idx in enumerate(top_indices)  # Loop through top indices
    ]

    # Construct result dictionary
    result = {
                f"lhs_field_index": selected_index,
                f"lhs_field_name": lhs_field,
                f"lhs_field_description": lhs_desc,
                f"lhs_field_data_type": lhs_type,
                "matches": matches
            }

    # Return final JSON output
    return {"results": [result]}


# User inputs
enter_index = int(input("Enter the index from LHS to process: "))
top_n = int(input("Enter the number of top similar sentences to retrieve (N): ") or 3)

# Retrieve and display results
output_json = retrieve_top_similar_sentences_json(
    enter_index, top_n, normalized_similarity_matrix, df1, df2, column1, column2, type_mapping
)

print(json.dumps(output_json, indent=2))
# Out:
# {
#   "results": [
#     {
#       "lhs_field_index": 4,
#       "lhs_field_name": "LAEDA",
#       "lhs_field_description": "Date of Last Change",
#       "lhs_field_data_type": "DATS",
#       "matches": [
#         {
#           "rank": 1,
#           "rhs_field_score": 0.8116681575775146,
#           "rhs_index": 33,
#           "rhs_field_name": "Cost Eff End date",
#           "rhs_field_desc": "Effective End  date",
#           "rhs_data_type": "TEXT",
#           "compatibility": "Incompatible"
#         },
#         {
#           "rank": 2,
#           "rhs_field_score": 0.7582371234893799,
#           "rhs_index": 177,
#           "rhs_field_name": "item Dimension Effective Start date",
#           "rhs_field_desc": "Effective Start date ; every time we changes the date, the latest start date will be captured (SCD-1)",
#           "rhs_data_type": "FLOAT",
#           "compatibility": "Incompatible"
#         },
#         {
#           "rank": 3,
#           "rhs_field_score": 0.7525774240493774,
#           "rhs_index": 38,
#           "rhs_field_name": "Equipment Eff Start date",
#           "rhs_field_desc": "Effective Start date",
#           "rhs_data_type": "TEXT",
#           "compatibility": "Incompatible"
#         }
#       ]
#     }
#   ]
# }

# %% [markdown]
# ONE TO MANY - Below code gets the topN similarities from RHS for particular index on LHS and shows if data types are compatible

# %%
import json
import numpy as np
import pandas as pd

# Function to retrieve top-N most similar sentences with data type validation
def retrieve_top_similar_sentences_json(selected_index, top_n, similarity_matrix, df1, df2, column1, column2, type_mapping):
    # Initialize variables
    similarities = similarity_matrix[selected_index]
    top_indices = np.argsort(similarities)[-top_n:][::-1]  # Top-N indices sorted in descending order
    
    lhs_field = df1.loc[selected_index, 'Field Name']  # LHS field name
    lhs_desc = df1.loc[selected_index, column1]        # LHS description
    lhs_type = df1.loc[selected_index, 'Data_Type']    # LHS data type
    
    # List to store all matches
    matches = [
        {
            "rank": rank + 1,
            "rhs_field_score": float(similarities[idx]),
            "rhs_index": int(df2.index[idx]),
            "rhs_field_name": df2.loc[idx, 'Attribute'],   # RHS attribute name
            "rhs_field_desc": df2.loc[idx, column2],       # RHS description
            "rhs_data_type": df2.loc[idx, 'Data_Type'],    # RHS data type
            "compatibility": "Compatible" if df2.loc[idx, 'Data_Type'] in type_mapping.get(lhs_type, []) else "Incompatible"
        }
        for rank, idx in enumerate(top_indices)  # Loop through top indices
        if (rhs_type := df2.loc[idx, 'Data_Type']) in type_mapping.get(lhs_type, [])

    ]

    # Construct result dictionary
    result = {
                f"lhs_field_index": selected_index,
                f"lhs_field_name": lhs_field,
                f"lhs_field_description": lhs_desc,
                f"lhs_field_data_type": lhs_type,
                "matches": matches
            }

    # Return final JSON output
    return {"results": [result]}


# User inputs
enter_index = int(input("Enter the index from LHS to process: "))
top_n = int(input("Enter the number of top similar sentences to retrieve (N): ") or 3)

# Retrieve and display results
output_json = retrieve_top_similar_sentences_json(
    enter_index, top_n, normalized_similarity_matrix, df1, df2, column1, column2, type_mapping
)

print(json.dumps(output_json, indent=2))
# Out:
# {
#   "results": [
#     {
#       "lhs_field_index": 4,
#       "lhs_field_name": "LAEDA",
#       "lhs_field_description": "Date of Last Change",
#       "lhs_field_data_type": "DATS",
#       "matches": []
#     }
#   ]
# }

# %% [markdown]
#                                                     Version 3

# %% [markdown]
# Version 3-
#
# -> Updated the data type check with extension version such that we can add any database in future.
#
# -> Uodated the code with more information showing in results
#
# -> Updated such that it shows only similarities based on datatype compatibility = true

# %%
import os
import json

# %%
mappings_dir = r"C:\Users\Yasvanth.Pamidi\OneDrive - ENCORA\Desktop\VSC\DataMapper\versions\mappings"
#mappings_dir = r'/Users/rebeca.mendoza/Desktop/Data_Mapper/mappings_dir'

# %% [markdown]
# load_mappings :
#
# -> Initializes an empty dictionary to store database mappings
#
# -> Checks if the specified directory exists. If not, raises a FileNotFoundError
#
# -> Iterates through files in the directory: Selects only .json files, excluding compatibilities.json. Extracts the database name from the filename. Opens the JSON file in read mode, reads its contents using json.load, and stores it in the mappings dictionary under the respective database name.
#
# -> Checks if no mappings were loaded and raises a ValueError.
#
# -> Returns the mappings dictionary containing database-to-data type mappings.

# %%
def load_mappings(mappings_dir):
    mappings = {} # Initializes an empty dictionary to store database mappings

    print(f"Loading mappings from directory: {mappings_dir}")

    if not os.path.exists(mappings_dir):
        raise FileNotFoundError(f"Mappings directory '{mappings_dir}' does not exist.") #Checks if the specified directory exists. If not, raises a FileNotFoundError
    for filename in os.listdir(mappings_dir):
        if filename.endswith(".json") and filename != "compatibilities.json":
            database_name = os.path.splitext(filename)[0]

            print(f"Processing file: {filename} as database: {database_name}")
            
            with open(os.path.join(mappings_dir, filename), "r") as file:
                mappings[database_name] = json.load(file) #Iterates through files in the directory: Selects only .json files, excluding compatibilities.json. Extracts the database name from the filename. Reads the JSON file and loads its content into the mappings dictionary.

                print(f"Loaded mapping for {database_name}: {mappings[database_name]}")
    
    if not mappings:
        raise ValueError(f"No mapping files found in '{mappings_dir}'.") #Checks if no mappings were loaded and raises a ValueError.
    
    print("Mappings loaded successfully:", mappings)
    return mappings #Returns the mappings dictionary containing database-to-data type mappings.

# %% [markdown]
# load_compatibilities: Reads the compatibility JSON file and loads it into a Python dictionary.

# %%
def load_compatibilities(file_path):
    with open(file_path, 'r') as file:
        return json.load(file)

# %% [markdown]
# normalize_data_type:
#
# -> Normalizes the data type of a field by converting it to lowercase
#
# -> Prepares a list to store databases where a match is found.
#
# -> Iterates through each database in the mappings.
#
# -> Converts all keys in the mapping to lowercase to ensure case-insensitive lookup.
#
# -> If a match for rhs_type_lower is found, it: Updates normalized_type. Adds the database to matching_databases.
#
# -> If matches are found, returns the normalized type and list of matching databases. Otherwise, returns the original type (converted to uppercase) and None.

# %%
def normalize_data_type(rhs_type,database_context, mappings):
    
    print(f"\nNormalizing RHS Type: {rhs_type} using mappings")
    
    rhs_type_lower = rhs_type.lower()

    print(f"Lowercase RHS Type: {rhs_type_lower}")

    matching_databases = []
    normalized_type = None #Normalizes the data type of a field by converting it to lowercase, Prepares a list to store databases where a match is found.

    for db_name, db_mapping in mappings.items():

        print(f"Checking database: {db_name}")

        normalized = {k.lower(): v for k, v in db_mapping.items()}.get(rhs_type_lower)
        if normalized:
            normalized_type = normalized
            matching_databases.append(db_name)

            print(f"Match found in {db_name}: Normalized Type -> {normalized_type}")

    if matching_databases:
        
        print(f"Final Normalized Type: {normalized_type}, Matching Databases: {matching_databases}")

        return normalized_type, matching_databases
    
    
    print(f"No matches found. Returning RHS Type in uppercase: {rhs_type.upper()}")

    return rhs_type.upper(), None

# %% [markdown]
# are_compatible:
#
# Purpose: Checks if two data types (lhs_type and rhs_type) are compatible.
#
# -> Converts both types to uppercase for consistency.
#
# -> Checks: 1:If the two types are identical. 2:If rhs_type exists in the compatibility list of lhs_type.

# %%
def are_compatible(lhs_type, rhs_type, compatibilities):
    lhs_type = lhs_type.upper()
    rhs_type = rhs_type.upper()
    return lhs_type == rhs_type or rhs_type in compatibilities.get(lhs_type, [])

# %%
def retrieve_top_similar_sentences_json(selected_index, top_n, normalized_similarity_matrix, df1, df2, column1, column2, type_mapping, compatibilities, filter_compatible=True):
    if normalized_similarity_matrix.shape != (len(df1), len(df2)):

        print(f"Error: Similarity matrix shape {normalized_similarity_matrix.shape} does not match dataframes: LHS {len(df1)}, RHS {len(df2)}")

        raise ValueError("The similarity matrix dimensions must match the LHS and RHS datasets.")
    
    print("Input validation passed. Proceeding...")
    
    similarities = normalized_similarity_matrix[selected_index]
    matches = []
    for idx in range(len(similarities)):
        rhs_field = df2.loc[idx, 'Attribute']
        rhs_desc = df2.loc[idx, column2]
        rhs_type = df2.loc[idx, 'Data_Type']

        print(f"\nProcessing RHS Index {idx}:")
        print(f"  Field: {rhs_field}, Description: {rhs_desc}, Type: {rhs_type}")

        database_context = df2.loc[idx, 'Database'] if 'Database' in df2.columns else "default_database"
        normalized_rhs_type, database_context = normalize_data_type(rhs_type, None, type_mapping)

        print(f"  Normalized RHS Type: {normalized_rhs_type}, Database Context: {database_context}")

        lhs_type = df1.loc[selected_index, 'Data_Type'].upper()
        normalized_lhs_type, _ = normalize_data_type(lhs_type, None, type_mapping)

        print(f"  LHS Type: {lhs_type}, Normalized LHS Type: {normalized_lhs_type}")

        normalized_rhs_type = normalized_rhs_type.upper()
        is_compatible = are_compatible(lhs_type, normalized_rhs_type, compatibilities)
        if is_compatible :
            matches.append({
                "rank": None,  # Placeholder to set rank later
                "similarity_score": float(similarities[idx]),
                "rhs_index": int(df2.index[idx]),
                "rhs_field_name": rhs_field,
                "rhs_field_desc": rhs_desc,
                "rhs_data_type": rhs_type,
                "normalized_rhs_type": normalized_rhs_type,
                "database_name": database_context if database_context else "Unknown",
                "compatibility": "Compatible",
            })
    matches = sorted(matches, key=lambda x: x["similarity_score"], reverse=True)

    print("\nSorted Matches by Similarity Score:")

    matches = matches[:top_n]
    for rank, match in enumerate(matches, start=1):
        match["rank"] = rank
    if not matches:
        matches.append({"message": "No compatible matches found."})
    lhs_field = df1.loc[selected_index,'Field Name']
    lhs_desc = df1.loc[selected_index, column1]
    lhs_type = df1.loc[selected_index, 'Data_Type']
    result = {
        "lhs_field_index": selected_index,
        "lhs_field_name": lhs_field,
        "lhs_field_description": lhs_desc,
        "lhs_field_data_type": lhs_type,
        "normalized_lhs_type": normalized_lhs_type,
        "matches": matches
    }
    return {"results": [result]}

type_mapping = load_mappings(mappings_dir)
compatibilities_file = os.path.join(mappings_dir, 'compatibilities.json')
compatibilities = load_compatibilities(compatibilities_file)

enter_index = int(input("Enter the index from LHS to process: "))
top_n = int(input("Enter the number of top similar sentences to retrieve (N): ") or 3)

check_length = True  #Adding Length

output_json = retrieve_top_similar_sentences_json(
    enter_index, top_n, normalized_similarity_matrix, df1, df2, "Description", "Description", type_mapping, compatibilities, filter_compatible=True
)
print(json.dumps(output_json, indent=2))
# Out:
# Loading mappings from directory: C:\Users\Yasvanth.Pamidi\OneDrive - ENCORA\Desktop\VSC\DataMapper\versions\mappings
# Processing file: pgsql_sql2023_map.json as database: pgsql_sql2023_map
# Loaded mapping for pgsql_sql2023_map: {'VARCHAR': 'VARCHAR', 'CHAR': 'CHAR', 'TEXT': 'VARCHAR(max)', 'BOOLEAN': 'BIT', 'SMALLINT': 'SMALLINT', 'INTEGER': 'INT', 'BIGINT': 'BIGINT', 'NUMERIC': 'NUMERIC', 'DECIMAL': 'DECIMAL', 'REAL': 'REAL', 'DOUBLE PRECISION': 'FLOAT', 'DATE': 'DATE', 'TIME': 'TIME', 'TIMESTAMP': 'TIMESTAMP', 'TIMESTAMPTZ': 'TIMESTAMP WITH TIME ZONE', 'JSON': 'JSON', 'JSONB': 'JSON', 'UUID': 'UNIQUEIDENTIFIER', 'BYTEA': 'VARBINARY(max)', 'ARRAY': 'ARRAY', 'XML': 'XML', 'CITEXT': 'VARCHAR'}
# Processing file: saphana_sql2023_map.json as database: saphana_sql2023_map
# Loaded mapping for saphana_sql2023_map: {'NVARCHAR': 'NVARCHAR', 'VARCHAR': 'VARCHAR', 'CHAR': 'CHAR', 'DATE': 'DATE', 'TIME': 'TIME', 'SECONDDATE': 'DATETIME2', 'TIMESTAMP': 'TIMESTAMP', 'DECIMAL': 'DECIMAL', 'SMALLINT': 'SMALLINT', 'INTEGER': 'INT', 'BIGINT': 'BIGINT', 'FLOAT': 'FLOAT', 'REAL': 'REAL', 'DOUBLE': 'FLOAT', 'CLOB': 'VARCHAR(max)', 'NCLOB': 'NVARCHAR(max)', 'BLOB': 'VARBINARY(max)', 'BOOLEAN': 'BIT', 'ST_GEOMETRY': 'JSON', 'ST_POINT': 'JSON', 'JSON': 'JSON', 'GUID': 'UNIQUEIDENTIFIER', 'TINYINT': 'SMALLINT'}
# Processing file: sapmara_sql2023_map.json as database: sapmara_sql2023_map
# Loaded mapping for sapmara_sql2023_map: {'clnt': 'VARCHAR', 'char': 'CHAR', 'dats': 'DATE', 'unit': 'VARCHAR', 'numc': 'NUMERIC', 'quan': 'FLOAT', 'dec': 'DECIMAL', 'int2': 'SMALLINT', 'int4': 'INT', 'curr': 'DECIMAL', 'flag': 'BIT', 'uuid': 'UNIQUEIDENTIFIER', 'bin': 'VARBINARY', 'json': 'JSON', 'time': 'TIME', 'timestamp': 'TIMESTAMP'}
# Mappings loaded successfully: {'pgsql_sql2023_map': {'VARCHAR': 'VARCHAR', 'CHAR': 'CHAR', 'TEXT': 'VARCHAR(max)', 'BOOLEAN': 'BIT', 'SMALLINT': 'SMALLINT', 'INTEGER': 'INT', 'BIGINT': 'BIGINT', 'NUMERIC': 'NUMERIC', 'DECIMAL': 'DECIMAL', 'REAL': 'REAL', 'DOUBLE PRECISION': 'FLOAT', 'DATE': 'DATE', 'TIME': 'TIME', 'TIMESTAMP': 'TIMESTAMP', 'TIMESTAMPTZ': 'TIMESTAMP WITH TIME ZONE', 'JSON': 'JSON', 'JSONB': 'JSON', 'UUID': 'UNIQUEIDENTIFIER', 'BYTEA': 'VARBINARY(max)', 'ARRAY': 'ARRAY', 'XML': 'XML', 'CITEXT': 'VARCHAR'}, 'saphana_sql2023_map': {'NVARCHAR': 'NVARCHAR', 'VARCHAR': 'VARCHAR', 'CHAR': 'CHAR', 'DATE': 'DATE', 'TIME': 'TIME', 'SECONDDATE': 'DATETIME2', 'TIMESTAMP': 'TIMESTAMP', 'DECIMAL': 'DECIMAL', 'SMALLINT': 'SMALLINT', 'INTEGER': 'INT', 'BIGINT': 'BIGINT', 'FLOAT': 'FLOAT', 'REAL': 'REAL', 'DOUBLE': 'FLOAT', 'CLOB': 'VARCHAR(max)', 'NCLOB': 'NVARCHAR(max)', 'BLOB': 'VARBINARY(max)', 'BOOLEAN': 'BIT', 'ST_GEOMETRY': 'JSON', 'ST_POINT': 'JSON', 'JSON': 'JSON', 'GUID': 'UNIQUEIDENTIFIER', 'TINYINT': 'SMALLINT'}, 'sapmara_sql2023_map': {'clnt': 'VARCHAR', 'char': 'CHAR', 'dats': 'DATE', 'unit': 'VARCHAR', 'numc': 'NUMERIC', 'quan': 'FLOAT', 'dec': 'DECIMAL', 'int2': 'SMALLINT', 'int4': 'INT', 'curr': 'DECIMAL', 'flag': 'BIT', 'uuid': 'UNIQUEIDENTIFIER', 'bin': 'VARBINARY', 'json': 'JSON', 'time': 'TIME', 'timestamp': 'TIMESTAMP'}}
# Input validation passed. Proceeding...
#
# Processing RHS Index 0:
#   Field: Shipper Contents Name, Description: Items that make up the shipper display  (i.e. M&Ms 3 flavor shipper display), Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 1:
#   Field: Shipper Contents Qty , Description: The quantity of each component item in a shipper display, Type: INTEGER
#
# Normalizing RHS Type: INTEGER using mappings
# Lowercase RHS Type: integer
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> INT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> INT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: INT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: INT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 2:
#   Field: Variety, Description: Variety of item, as defined by the MCoE at sub-category level. Attribute managed by MCoE, Type: VARCHAR
#
# Normalizing RHS Type: VARCHAR using mappings
# Lowercase RHS Type: varchar
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> VARCHAR
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: VARCHAR, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 3:
#   Field: GR Processing Time in days, Description: The time between the delivery or the production of a product and its availability in stores  (in days), Type: FLOAT
#
# Normalizing RHS Type: FLOAT using mappings
# Lowercase RHS Type: float
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> FLOAT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: FLOAT, Matching Databases: ['saphana_sql2023_map']
#   Normalized RHS Type: FLOAT, Database Context: ['saphana_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 4:
#   Field: SAP Global Article Status, Description: The cross-plant material status restricts the usability of the material for all plants, that is, it defines whether a warning or error message is displayed if you include the material in a particular function. Defualts to Active on set up ; going forward the cat team will use htis attribute to de-active an item, Type: BOOLEAN
#
# Normalizing RHS Type: BOOLEAN using mappings
# Lowercase RHS Type: boolean
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> BIT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> BIT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: BIT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: BIT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 5:
#   Field: Serve Temperature, Description: temperature of the product, Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 6:
#   Field: MDM Status effective date, Description: The date from which the article status is effective, Type: BOOLEAN
#
# Normalizing RHS Type: BOOLEAN using mappings
# Lowercase RHS Type: boolean
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> BIT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> BIT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: BIT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: BIT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 7:
#   Field: Seasonal indicator, Description: Indicates whether the product is sold seasonally or every day, Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 8:
#   Field: F&R exception messages (Other Wawa Specific Data in SAP), Description: Used by F&R system to process exception messages used for inventory accuracy by stores, Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 9:
#   Field: Labor Scheduler Code, Description: Used for labor scheduler to put away deliveries, Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 10:
#   Field: Item Type (WBC Reporting), Description: nan, Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 11:
#   Field: SAP Article Status Validity Date (System entered date), Description: The valid-from date of the material status is considered only if it precedes or is the same as the planning date. This denotes the sell end date of the Item/ingredient/product, Type: BOOLEAN
#
# Normalizing RHS Type: BOOLEAN using mappings
# Lowercase RHS Type: boolean
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> BIT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> BIT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: BIT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: BIT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 12:
#   Field: External Merchandise Category, Description: SAP is External Material Group.  External Merchandise Category links the inventory from one article to another.  This process occurs in the nightly runs. There are defined groups of articles that this is maintained on: Bakery, Coffee and blends), Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 13:
#   Field: Pct (% ) Juice, Description: % of each type of juice in product (Tax??), Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 14:
#   Field: Is this product Vegetarian?, Description: lacto-ovo.Made without meat but may contain egg, milk, animal derived enzymes/sub ingredients , Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 15:
#   Field: Is this product Vegan?, Description: products do not contain ingredients of meat, fish, fowl, animal by-products, eggs or egg products, milk or milk products, honey or honey bee products. Involve no animal testing of ingredients by supplier, producer, manufacturer or independent party. , Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 16:
#   Field: Grams of Whole Grain - per 100g, Description: Amount of whole grains in grams per 100g of product , Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 17:
#   Field: Is this product Kosher? , Description: Kosher , Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 18:
#   Field: reduced fat , Description: reduced fat , Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 19:
#   Field: USDA grade , Description: USDA grade , Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 20:
#   Field: Is this product certified organic, Description: Organic, Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 21:
#   Field: manufacturer suggested MSRP, Description: Sugested MSRP from manufacturer, Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 22:
#   Field: Master case cost, Description: Cost to the distributor or store for the master case; (Applicable for Tobacco also), Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 23:
#   Field: IP  cost, Description: Cost to the distributor or store for the inner pack, Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 24:
#   Field: Unit (EA) cost, Description: Cost to the distributor or store for the each, Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 25:
#   Field: Shipper contents unit cost, Description: The cost of each of the contents of a shipper display, Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 26:
#   Field: Is this product lactose free? , Description: lactose free , Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 27:
#   Field: add on flag
# Variable Load Fee (Gift Cards) ?, Description: Additional fee charged to a gift card customer to activate the card. Gift cards with variable retails have added service fees.  The variable load fee box on the NIF tells us which fee to assign using the add on field in SAP., Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 28:
#   Field: Cost -label Charge, Description: The additional cost added to an item for a label - FL only.
# Currenty added to PB00 ; does not show up as a separate cost condition today, Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 29:
#   Field: Tobacco Carton Cost ?, Description: nan, Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 30:
#   Field: Tobacco SSOI ?, Description: State Specific Off Invoice amount, Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 31:
#   Field: FL Transfer truck Indicator, Description: Indicates whether the item needs to be transported on a truck from MA to FL ; transfer between WBC / NJDC  to MSE , Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 32:
#   Field: Cost Eff Start date, Description: Effective Start date, Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 33:
#   Field: Cost Eff End date, Description: Effective End  date, Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 34:
#   Field: Purchasing Bracket, Description: The price bracketin which the distributor typically purchases from the manufacturer based on quantity, Type: INTEGER
#
# Normalizing RHS Type: INTEGER using mappings
# Lowercase RHS Type: integer
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> INT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> INT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: INT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: INT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 35:
#   Field: Cycle count category, Description: Drives Operational process for Cycle Counts within the Stores ; Interface with Cycle count system/Refernce data system for list of reference values for this category , Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 36:
#   Field: Equipment Name, Description: Name of the equipment; (RACI is different ), Type: VARCHAR
#
# Normalizing RHS Type: VARCHAR using mappings
# Lowercase RHS Type: varchar
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> VARCHAR
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: VARCHAR, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 37:
#   Field: Equipment Model, Description: Equipment model number from the manufacturer, Type: BIGINT
#
# Normalizing RHS Type: BIGINT using mappings
# Lowercase RHS Type: bigint
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> BIGINT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> BIGINT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: BIGINT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: BIGINT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 38:
#   Field: Equipment Eff Start date, Description: Effective Start date, Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 39:
#   Field: Estimated forecast per week for the Market (MA / FL estimated forecast per week), Description: Number of shipping units expected to be sold in 1 week in FL  market, Type: BIGINT
#
# Normalizing RHS Type: BIGINT using mappings
# Lowercase RHS Type: bigint
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> BIGINT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> BIGINT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: BIGINT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: BIGINT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 40:
#   Field: ABC Indicator, Description: This is used to calculate "safety stock" and inventory accuracy.  This metric is used by the entire supply chain.  Classifies an article as an A, B, or C part according to its consumption value.  All article start out classified as “N” for new and are then re-evaluated for status change quarterly. , Type: BOOLEAN
#
# Normalizing RHS Type: BOOLEAN using mappings
# Lowercase RHS Type: boolean
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> BIT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> BIT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: BIT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: BIT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 41:
#   Field: Wawa Proprietary, Description: Indicates whether item is proprietary to Wawa; Appliable for MSE - Indicates if the item is bought in only for wawa .(Applicable only for MSE - Dana Voss - 6/8/20), Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 42:
#   Field: POS Item Type , Description: SAP ZZPOS1 on Wawa specific tab, Determines product code in POS outbound processing. Product code is used to validate card activation., Type: BIGINT
#
# Normalizing RHS Type: BIGINT using mappings
# Lowercase RHS Type: bigint
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> BIGINT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> BIGINT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: BIGINT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: BIGINT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 43:
#   Field: recommended method(s) of storage, Description: Values: Ambient , frozen , refrigerated . Indicates recommended storage method for the item by the supplier., Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 44:
#   Field: Wawa Package , Description: SAP Wawa specific tab "package".  Type of package for reporting & merchndizing & assortment planning   . Eg: Standard , King , Junior etc, Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 45:
#   Field: Listing Store Id, Description: Store Id; Read out from JDA; Interface from JDA, Type: BIGINT
#
# Normalizing RHS Type: BIGINT using mappings
# Lowercase RHS Type: bigint
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> BIGINT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> BIGINT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: BIGINT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: BIGINT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 46:
#   Field: Tobacco / Alcohol Age restriction Indicator, Description: Indicates if there is a restriction on purchasing the product, Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# ...
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 434:
#   Field: Secondary Portion Size of Ingredient, Description: Determines the number / quantity of item base UOM that goes into 1 secondary  portion  of the Item . (i.e. scoop, pinch, handful) . Portion can be same as BUOM., Type: INTEGER
#
# Normalizing RHS Type: INTEGER using mappings
# Lowercase RHS Type: integer
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> INT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> INT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: INT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: INT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 435:
#   Field: multiplier of item for standard portion size, Description: The quantity of base UOM that makes up the standard portion size of the item at the ingredient level(eg: 2 Oz of Lettuce from taylor farms = 1 pinch of lettuce in recipe) . , Type: INTEGER
#
# Normalizing RHS Type: INTEGER using mappings
# Lowercase RHS Type: integer
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> INT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> INT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: INT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: INT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 436:
#   Field: multiplier of item for secondary portion size, Description: The quantity of base UOM that makes up the secondary portion size of the item at the ingredient level (eg: 2 Oz of Lettuce from taylor farms = 1 hand full of lettuce in recipe ) ., Type: INTEGER
#
# Normalizing RHS Type: INTEGER using mappings
# Lowercase RHS Type: integer
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> INT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> INT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: INT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: INT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 437:
#   Field: Offering Classification, Description: identifies if the product is offered thru Web, Catering lite , retil etc, Type: BIGINT
#
# Normalizing RHS Type: BIGINT using mappings
# Lowercase RHS Type: bigint
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> BIGINT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> BIGINT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: BIGINT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: BIGINT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 438:
#   Field: Distributor retail value by  Pricelist for multiple DSD distributors, Description: Retail price retrived from each distributor , Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 439:
#   Field: Product friendly Serving  Size, Description: The serving available in the Item . (determins how many people does the product serve), Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 440:
#   Field: Product Selling Unit of measure (For FPC,OO,OG), Description: Selling UOM for the product by Wawa to customer. The product can be sold in multiple Uom (coke as a single or pack of 8) . Eg:
# EA , IP , Scoops , Spoodles , Oz , Lb , tray etc, Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 441:
#   Field: Retail price(S) by Price  list by vendor (DSD multi-distributors only), Description: Retail price retrived from each price list the product is associated to . The product will have same nuber of Retail prices as the price list linked to it.defined by Merch category .(Merch cat need to be filled first), Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 442:
#   Field: Base  Unit of measure for FPC , OO , OG, Description: Lowest unit of measure at which the item can be broken down.  For ingredient items, the standard portion for an item is converted into this BUOM.
# Eg: EA , FOZ, OZ, Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 443:
#   Field: Sellable Product  Indicator, Description: Defines if the sell side product is sellable, Type: BIGINT
#
# Normalizing RHS Type: BIGINT using mappings
# Lowercase RHS Type: bigint
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> BIGINT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> BIGINT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: BIGINT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: BIGINT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 444:
#   Field: Item flavor, Description: flavor of the item, Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 445:
#   Field: Content Only  Indicator, Description: Flag to indicate Content Only when the supplier determines that an item needs to be set up, Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 446:
#   Field: Does this SAP Article have multipel suppliers (Blend/Subs), Description: Field to desigate if this item is sourced from multiple suppliers. , Type: TEXT
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 447:
#   Field: MDM Status effective date for Item - Ingredient association, Description: The date from which the item - Ingredient association is valid, Type: BIGINT
#
# Normalizing RHS Type: BIGINT using mappings
# Lowercase RHS Type: bigint
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> BIGINT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> BIGINT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: BIGINT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: BIGINT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Processing RHS Index 448:
#   Field: Ingredient Standard Portion Size Unit of Measure (UOM) QTY, Description: Determines the number / quantity of item Base UOM that goes into 1 standard portion  of the Item .(i.e. scoop, pinch, handful) . Portion can be same as BUOM., Type: INTEGER
#
# Normalizing RHS Type: INTEGER using mappings
# Lowercase RHS Type: integer
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> INT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> INT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: INT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: INT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: DATS using mappings
# Lowercase RHS Type: dats
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> DATE
# Final Normalized Type: DATE, Matching Databases: ['sapmara_sql2023_map']
#   LHS Type: DATS, Normalized LHS Type: DATE
#
# Sorted Matches by Similarity Score:
# {
#   "results": [
#     {
#       "lhs_field_index": 4,
#       "lhs_field_name": "LAEDA",
#       "lhs_field_description": "Date of Last Change",
#       "lhs_field_data_type": "DATS",
#       "normalized_lhs_type": "DATE",
#       "matches": [
#         {
#           "message": "No compatible matches found."
#         }
#       ]
#     }
#   ]
# }

# %% [markdown]
#                                                     Version-4

# %% [markdown]
# Version 4-
#
# ->  Added length compatibility.
# -> Added functionality for user to select similarity score threshold

# %% [markdown]
# normalize_length:
#
# Purpose: Converts a length to an integer.
#
# Logic: If the length is invalid (e.g., non-numeric or None), it returns None.

# %%
def normalize_length(length):
    try:
        return int(length)
    except (ValueError, TypeError):
        return None

# %% [markdown]
# Purpose: Determines if two lengths are compatible.
#
# Logic:
#
# -> If check_length is False, compatibility check is skipped
#
# -> Normalizes lengths to ensure valid numerical values.
#
# -> Handles missing values by returning False.
#
# -> checks for logic

# %%
def is_length_compatible(lhs_length, rhs_length, check_length=True):
    """
    Checks if the LHS length is compatible with the RHS length.

    - If `check_length` is False, it always returns True.
    - If lengths are not valid integers, it returns False.
    - Returns True if `lhs_length` is less than or equal to `rhs_length`.

    Args:
        lhs_length: The length of the column from the LHS dataset.
        rhs_length: The length of the column from the RHS dataset.
        check_length (bool): Flag to enable or disable length checking.

    Returns:
        bool: True if compatible, False otherwise.
    """
    if not check_length:
        return True
    
    lhs_length = normalize_length(lhs_length)
    rhs_length = normalize_length(rhs_length)

    print(f"LHS Length: {lhs_length}, RHS Length: {rhs_length}")
    
    if lhs_length is None or rhs_length is None:
        print("One of the lengths is invalid. Returning False.")
        return False
    
    if lhs_length <= rhs_length:  # Fixed missing colon
        return True  # Ensures proper logical flow
    
    return False  # Explicit return if the condition is not met

# %%
# Function to convert numpy types to native Python types
def convert_to_native_type(value):
    if isinstance(value, (np.integer, np.int64)):
        return int(value)
    elif isinstance(value, (np.floating, np.float64)):
        return float(value)
    elif isinstance(value, np.ndarray):
        return value.tolist()
    else:
        return value

# %% [markdown]
# updated main function for length compatible with similarity score threshould user input

# %%
def retrieve_top_similar_sentences_json(selected_index, top_n, normalized_similarity_matrix, df1, df2, column1, column2, type_mapping, compatibilities, filter_compatible=True):
    
    """
    Retrieves the top similar sentences based on a similarity matrix while checking compatibility.

    Args:
        selected_index (int): Index of the LHS column to compare.
        top_n (int): Number of top matches to return.
        normalized_similarity_matrix (np.array): Precomputed similarity scores.
        df1 (pd.DataFrame): LHS dataset.
        df2 (pd.DataFrame): RHS dataset.
        column1 (str): Column name for description in LHS.
        column2 (str): Column name for description in RHS.
        type_mapping (dict): Mapping of data types.
        compatibilities (dict): Compatibility mapping.
        similarity_threshold (float): Minimum similarity score for a match.
        filter_compatible (bool, optional): Whether to filter only compatible matches. Defaults to True.

    Returns:
        dict: JSON output with matched results.
    """

    if normalized_similarity_matrix.shape != (len(df1), len(df2)):

        print(f"Error: Similarity matrix shape {normalized_similarity_matrix.shape} does not match dataframes: LHS {len(df1)}, RHS {len(df2)}")
        raise ValueError("The similarity matrix dimensions must match the LHS and RHS datasets.")
    
    print("Input validation passed. Processing similarity matches...")

    similarities = normalized_similarity_matrix[selected_index]
    matches = []

    normalized_lhs_type = None

    for idx in range(len(similarities)):
        similarity_score = float(similarities[idx])  # Extract similarity score
        if similarity_score < similarity_threshold:
            continue  # Skip if below threshold

        rhs_field = df2.loc[idx, 'Attribute']
        rhs_desc = df2.loc[idx, column2]
        rhs_type = df2.loc[idx, 'Data_Type']
        rhs_length = df2.loc[idx, 'Length'] # RHS length

        print(f"\nProcessing RHS Index {idx}:")
        print(f"  Field: {rhs_field}, Description: {rhs_desc}, Type: {rhs_type}, Length: {rhs_length}")

        database_context = df2.loc[idx, 'Database'] if 'Database' in df2.columns else "default_database"
        normalized_rhs_type, database_context = normalize_data_type(rhs_type, None, type_mapping)

        print(f"  Normalized RHS Type: {normalized_rhs_type}, Database Context: {database_context}")

        lhs_type = df1.loc[selected_index, 'Data_Type'].upper()
        lhs_length = df1.loc[selected_index, 'Length']  # LHS length
        normalized_lhs_type, _ = normalize_data_type(lhs_type, None, type_mapping)

        print(f"  LHS Type: {lhs_type}, Normalized LHS Type: {normalized_lhs_type}")

        normalized_rhs_type = normalized_rhs_type.upper()
        is_compatible = are_compatible(lhs_type, normalized_rhs_type, compatibilities)

        # Normalize length before checking compatibility
        #lhs_length = normalize_length(lhs_length)
        #rhs_length = normalize_length(rhs_length)

        length_compatible = is_length_compatible(lhs_length, rhs_length, check_length=True)
        
        print(f"length_compatible: {length_compatible}")

        if is_compatible and length_compatible:
            matches.append({
                "rank": None,  # Placeholder to set rank later
                "similarity_score": similarity_score,
                "rhs_index": int(df2.index[idx]),
                "rhs_field_name": rhs_field,
                "rhs_field_desc": rhs_desc,
                "rhs_data_type": rhs_type,
                "normalized_rhs_type": normalized_rhs_type,
                "database_name": database_context if database_context else "Unknown",
                "rhs_length": convert_to_native_type(rhs_length),
                "compatibility": "Compatible"
                 
            })

    # Sort matches by similarity score (descending)
    matches = sorted(matches, key=lambda x: x["similarity_score"], reverse=True)[:top_n]

    print("\nSorted Matches by Similarity Score:")

    for rank, match in enumerate(matches, start=1):
        match["rank"] = rank

    if not matches:
        matches.append({"message": "No compatible matches found."})

    # Fetch LHS details safely
    lhs_field = df1.loc[selected_index,'Field Name']
    lhs_desc = df1.loc[selected_index, column1]
    lhs_type = df1.loc[selected_index, 'Data_Type']
    lhs_length = df1.loc[selected_index, 'Length']   

    result = {
        "lhs_field_index": selected_index,
        "lhs_field_name": lhs_field,
        "lhs_field_description": lhs_desc,
        "lhs_field_data_type": lhs_type,
        "normalized_lhs_type": normalized_lhs_type,
        "lhs_field_length": convert_to_native_type(lhs_length),  
        "matches": matches
    }

    return {"results": [result]}

# Load type mappings and compatibilities
type_mapping = load_mappings(mappings_dir)
compatibilities_file = os.path.join(mappings_dir, 'compatibilities.json')
compatibilities = load_compatibilities(compatibilities_file)


# User Input with Validations

# Validate LHS Index
while True:
    try:
        enter_index = int(input("Enter the index from LHS to process: "))
        if 0<= enter_index <len(df1): # Ensure it's within range
            break
        else:
            print(f"Error: Index out of range. Please enter a value between 0 and {len(df1) - 1}.")
    except ValueError:
        print("Invalid input. Please enter a valid integer.")


# Validate Top N
while True:
    try:
        top_n = int(input("Enter the number of top similar sentences to retrieve (N): ") or 3)
        if top_n > 0:
            break
        else:
            print("Error: Please enter a positive integer greater than 0.")
    except ValueError:
        print("Invalid input. Please enter a valid integer.")

# Validate Similarity Score Threshold
while True:
    try:
        similarity_threshold = float(input("Enter the similarity score threshold (0.0 - 1.0): "))
        if 0.0 <= similarity_threshold <= 1.0:
            break
        else:
            print("Error: Please enter a value between 0.0 and 1.0.")
    except ValueError:
        print("Invalid input. Please enter a numeric value between 0.0 and 1.0.")

output_json = retrieve_top_similar_sentences_json(
    enter_index, top_n, normalized_similarity_matrix, df1, df2, "Description", "Description", type_mapping, compatibilities,similarity_threshold)
print(json.dumps(output_json, indent=2))
# Out:
# Loading mappings from directory: C:\Users\Yasvanth.Pamidi\OneDrive - ENCORA\Desktop\VSC\DataMapper\versions\mappings
# Processing file: pgsql_sql2023_map.json as database: pgsql_sql2023_map
# Loaded mapping for pgsql_sql2023_map: {'VARCHAR': 'VARCHAR', 'CHAR': 'CHAR', 'TEXT': 'VARCHAR(max)', 'BOOLEAN': 'BIT', 'SMALLINT': 'SMALLINT', 'INTEGER': 'INT', 'BIGINT': 'BIGINT', 'NUMERIC': 'NUMERIC', 'DECIMAL': 'DECIMAL', 'REAL': 'REAL', 'DOUBLE PRECISION': 'FLOAT', 'DATE': 'DATE', 'TIME': 'TIME', 'TIMESTAMP': 'TIMESTAMP', 'TIMESTAMPTZ': 'TIMESTAMP WITH TIME ZONE', 'JSON': 'JSON', 'JSONB': 'JSON', 'UUID': 'UNIQUEIDENTIFIER', 'BYTEA': 'VARBINARY(max)', 'ARRAY': 'ARRAY', 'XML': 'XML', 'CITEXT': 'VARCHAR'}
# Processing file: saphana_sql2023_map.json as database: saphana_sql2023_map
# Loaded mapping for saphana_sql2023_map: {'NVARCHAR': 'NVARCHAR', 'VARCHAR': 'VARCHAR', 'CHAR': 'CHAR', 'DATE': 'DATE', 'TIME': 'TIME', 'SECONDDATE': 'DATETIME2', 'TIMESTAMP': 'TIMESTAMP', 'DECIMAL': 'DECIMAL', 'SMALLINT': 'SMALLINT', 'INTEGER': 'INT', 'BIGINT': 'BIGINT', 'FLOAT': 'FLOAT', 'REAL': 'REAL', 'DOUBLE': 'FLOAT', 'CLOB': 'VARCHAR(max)', 'NCLOB': 'NVARCHAR(max)', 'BLOB': 'VARBINARY(max)', 'BOOLEAN': 'BIT', 'ST_GEOMETRY': 'JSON', 'ST_POINT': 'JSON', 'JSON': 'JSON', 'GUID': 'UNIQUEIDENTIFIER', 'TINYINT': 'SMALLINT'}
# Processing file: sapmara_sql2023_map.json as database: sapmara_sql2023_map
# Loaded mapping for sapmara_sql2023_map: {'clnt': 'VARCHAR', 'char': 'CHAR', 'dats': 'DATE', 'unit': 'VARCHAR', 'numc': 'NUMERIC', 'quan': 'FLOAT', 'dec': 'DECIMAL', 'int2': 'SMALLINT', 'int4': 'INT', 'curr': 'DECIMAL', 'flag': 'BIT', 'uuid': 'UNIQUEIDENTIFIER', 'bin': 'VARBINARY', 'json': 'JSON', 'time': 'TIME', 'timestamp': 'TIMESTAMP'}
# Mappings loaded successfully: {'pgsql_sql2023_map': {'VARCHAR': 'VARCHAR', 'CHAR': 'CHAR', 'TEXT': 'VARCHAR(max)', 'BOOLEAN': 'BIT', 'SMALLINT': 'SMALLINT', 'INTEGER': 'INT', 'BIGINT': 'BIGINT', 'NUMERIC': 'NUMERIC', 'DECIMAL': 'DECIMAL', 'REAL': 'REAL', 'DOUBLE PRECISION': 'FLOAT', 'DATE': 'DATE', 'TIME': 'TIME', 'TIMESTAMP': 'TIMESTAMP', 'TIMESTAMPTZ': 'TIMESTAMP WITH TIME ZONE', 'JSON': 'JSON', 'JSONB': 'JSON', 'UUID': 'UNIQUEIDENTIFIER', 'BYTEA': 'VARBINARY(max)', 'ARRAY': 'ARRAY', 'XML': 'XML', 'CITEXT': 'VARCHAR'}, 'saphana_sql2023_map': {'NVARCHAR': 'NVARCHAR', 'VARCHAR': 'VARCHAR', 'CHAR': 'CHAR', 'DATE': 'DATE', 'TIME': 'TIME', 'SECONDDATE': 'DATETIME2', 'TIMESTAMP': 'TIMESTAMP', 'DECIMAL': 'DECIMAL', 'SMALLINT': 'SMALLINT', 'INTEGER': 'INT', 'BIGINT': 'BIGINT', 'FLOAT': 'FLOAT', 'REAL': 'REAL', 'DOUBLE': 'FLOAT', 'CLOB': 'VARCHAR(max)', 'NCLOB': 'NVARCHAR(max)', 'BLOB': 'VARBINARY(max)', 'BOOLEAN': 'BIT', 'ST_GEOMETRY': 'JSON', 'ST_POINT': 'JSON', 'JSON': 'JSON', 'GUID': 'UNIQUEIDENTIFIER', 'TINYINT': 'SMALLINT'}, 'sapmara_sql2023_map': {'clnt': 'VARCHAR', 'char': 'CHAR', 'dats': 'DATE', 'unit': 'VARCHAR', 'numc': 'NUMERIC', 'quan': 'FLOAT', 'dec': 'DECIMAL', 'int2': 'SMALLINT', 'int4': 'INT', 'curr': 'DECIMAL', 'flag': 'BIT', 'uuid': 'UNIQUEIDENTIFIER', 'bin': 'VARBINARY', 'json': 'JSON', 'time': 'TIME', 'timestamp': 'TIMESTAMP'}}
# Input validation passed. Processing similarity matches...
#
# Processing RHS Index 0:
#   Field: Shipper Contents Name, Description: Items that make up the shipper display  (i.e. M&Ms 3 flavor shipper display), Type: TEXT, Length: 76
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 76
# length_compatible: True
#
# Processing RHS Index 1:
#   Field: Shipper Contents Qty , Description: The quantity of each component item in a shipper display, Type: INTEGER, Length: 56
#
# Normalizing RHS Type: INTEGER using mappings
# Lowercase RHS Type: integer
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> INT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> INT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: INT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: INT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 56
# length_compatible: True
#
# Processing RHS Index 2:
#   Field: Variety, Description: Variety of item, as defined by the MCoE at sub-category level. Attribute managed by MCoE, Type: VARCHAR, Length: 88
#
# Normalizing RHS Type: VARCHAR using mappings
# Lowercase RHS Type: varchar
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> VARCHAR
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: VARCHAR, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 88
# length_compatible: True
#
# Processing RHS Index 3:
#   Field: GR Processing Time in days, Description: The time between the delivery or the production of a product and its availability in stores  (in days), Type: FLOAT, Length: 102
#
# Normalizing RHS Type: FLOAT using mappings
# Lowercase RHS Type: float
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> FLOAT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: FLOAT, Matching Databases: ['saphana_sql2023_map']
#   Normalized RHS Type: FLOAT, Database Context: ['saphana_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 102
# length_compatible: True
#
# Processing RHS Index 4:
#   Field: SAP Global Article Status, Description: The cross-plant material status restricts the usability of the material for all plants, that is, it defines whether a warning or error message is displayed if you include the material in a particular function. Defualts to Active on set up ; going forward the cat team will use htis attribute to de-active an item, Type: BOOLEAN, Length: 312
#
# Normalizing RHS Type: BOOLEAN using mappings
# Lowercase RHS Type: boolean
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> BIT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> BIT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: BIT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: BIT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 312
# length_compatible: True
#
# Processing RHS Index 5:
#   Field: Serve Temperature, Description: temperature of the product, Type: TEXT, Length: 26
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 26
# length_compatible: True
#
# Processing RHS Index 6:
#   Field: MDM Status effective date, Description: The date from which the article status is effective, Type: BOOLEAN, Length: 51
#
# Normalizing RHS Type: BOOLEAN using mappings
# Lowercase RHS Type: boolean
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> BIT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> BIT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: BIT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: BIT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 51
# length_compatible: True
#
# Processing RHS Index 7:
#   Field: Seasonal indicator, Description: Indicates whether the product is sold seasonally or every day, Type: TEXT, Length: 61
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 61
# length_compatible: True
#
# Processing RHS Index 8:
#   Field: F&R exception messages (Other Wawa Specific Data in SAP), Description: Used by F&R system to process exception messages used for inventory accuracy by stores, Type: TEXT, Length: 86
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 86
# length_compatible: True
#
# Processing RHS Index 9:
#   Field: Labor Scheduler Code, Description: Used for labor scheduler to put away deliveries, Type: TEXT, Length: 47
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 47
# length_compatible: True
#
# Processing RHS Index 10:
#   Field: Item Type (WBC Reporting), Description: nan, Type: TEXT, Length: 3
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 3
# length_compatible: False
#
# Processing RHS Index 11:
#   Field: SAP Article Status Validity Date (System entered date), Description: The valid-from date of the material status is considered only if it precedes or is the same as the planning date. This denotes the sell end date of the Item/ingredient/product, Type: BOOLEAN, Length: 175
#
# Normalizing RHS Type: BOOLEAN using mappings
# Lowercase RHS Type: boolean
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> BIT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> BIT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: BIT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: BIT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 175
# length_compatible: True
#
# Processing RHS Index 12:
#   Field: External Merchandise Category, Description: SAP is External Material Group.  External Merchandise Category links the inventory from one article to another.  This process occurs in the nightly runs. There are defined groups of articles that this is maintained on: Bakery, Coffee and blends), Type: TEXT, Length: 245
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 245
# length_compatible: True
#
# Processing RHS Index 13:
#   Field: Pct (% ) Juice, Description: % of each type of juice in product (Tax??), Type: TEXT, Length: 42
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 42
# length_compatible: True
#
# Processing RHS Index 14:
#   Field: Is this product Vegetarian?, Description: lacto-ovo.Made without meat but may contain egg, milk, animal derived enzymes/sub ingredients , Type: TEXT, Length: 94
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 94
# length_compatible: True
#
# Processing RHS Index 17:
#   Field: Is this product Kosher? , Description: Kosher , Type: TEXT, Length: 7
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 7
# length_compatible: False
#
# Processing RHS Index 18:
#   Field: reduced fat , Description: reduced fat , Type: TEXT, Length: 12
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 12
# length_compatible: True
#
# Processing RHS Index 20:
#   Field: Is this product certified organic, Description: Organic, Type: TEXT, Length: 7
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 7
# length_compatible: False
#
# Processing RHS Index 21:
#   Field: manufacturer suggested MSRP, Description: Sugested MSRP from manufacturer, Type: TEXT, Length: 31
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 31
# length_compatible: True
#
# Processing RHS Index 22:
#   Field: Master case cost, Description: Cost to the distributor or store for the master case; (Applicable for Tobacco also), Type: TEXT, Length: 83
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 83
# length_compatible: True
#
# Processing RHS Index 23:
#   Field: IP  cost, Description: Cost to the distributor or store for the inner pack, Type: TEXT, Length: 51
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 51
# length_compatible: True
#
# Processing RHS Index 24:
#   Field: Unit (EA) cost, Description: Cost to the distributor or store for the each, Type: TEXT, Length: 45
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 45
# length_compatible: True
#
# Processing RHS Index 25:
#   Field: Shipper contents unit cost, Description: The cost of each of the contents of a shipper display, Type: TEXT, Length: 53
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 53
# length_compatible: True
#
# Processing RHS Index 27:
#   Field: add on flag
# Variable Load Fee (Gift Cards) ?, Description: Additional fee charged to a gift card customer to activate the card. Gift cards with variable retails have added service fees.  The variable load fee box on the NIF tells us which fee to assign using the add on field in SAP., Type: TEXT, Length: 224
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 224
# length_compatible: True
#
# Processing RHS Index 28:
#   Field: Cost -label Charge, Description: The additional cost added to an item for a label - FL only.
# Currenty added to PB00 ; does not show up as a separate cost condition today, Type: TEXT, Length: 136
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 136
# length_compatible: True
#
# Processing RHS Index 29:
#   Field: Tobacco Carton Cost ?, Description: nan, Type: TEXT, Length: 3
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 3
# length_compatible: False
#
# Processing RHS Index 30:
#   Field: Tobacco SSOI ?, Description: State Specific Off Invoice amount, Type: TEXT, Length: 33
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 33
# length_compatible: True
#
# Processing RHS Index 31:
#   Field: FL Transfer truck Indicator, Description: Indicates whether the item needs to be transported on a truck from MA to FL ; transfer between WBC / NJDC  to MSE , Type: TEXT, Length: 114
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 114
# length_compatible: True
#
# Processing RHS Index 32:
#   Field: Cost Eff Start date, Description: Effective Start date, Type: TEXT, Length: 20
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 20
# length_compatible: True
#
# Processing RHS Index 33:
#   Field: Cost Eff End date, Description: Effective End  date, Type: TEXT, Length: 19
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 19
# length_compatible: True
#
# Processing RHS Index 34:
#   Field: Purchasing Bracket, Description: The price bracketin which the distributor typically purchases from the manufacturer based on quantity, Type: INTEGER, Length: 101
#
# Normalizing RHS Type: INTEGER using mappings
# Lowercase RHS Type: integer
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> INT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> INT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: INT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: INT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 101
# length_compatible: True
#
# Processing RHS Index 35:
#   Field: Cycle count category, Description: Drives Operational process for Cycle Counts within the Stores ; Interface with Cycle count system/Refernce data system for list of reference values for this category , Type: TEXT, Length: 166
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 166
# length_compatible: True
#
# Processing RHS Index 36:
#   Field: Equipment Name, Description: Name of the equipment; (RACI is different ), Type: VARCHAR, Length: 43
#
# Normalizing RHS Type: VARCHAR using mappings
# Lowercase RHS Type: varchar
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> VARCHAR
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: VARCHAR, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 43
# length_compatible: True
#
# Processing RHS Index 37:
#   Field: Equipment Model, Description: Equipment model number from the manufacturer, Type: BIGINT, Length: 44
#
# Normalizing RHS Type: BIGINT using mappings
# Lowercase RHS Type: bigint
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> BIGINT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> BIGINT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: BIGINT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: BIGINT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 44
# length_compatible: True
#
# Processing RHS Index 38:
#   Field: Equipment Eff Start date, Description: Effective Start date, Type: TEXT, Length: 20
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 20
# length_compatible: True
#
# Processing RHS Index 39:
#   Field: Estimated forecast per week for the Market (MA / FL estimated forecast per week), Description: Number of shipping units expected to be sold in 1 week in FL  market, Type: BIGINT, Length: 68
#
# Normalizing RHS Type: BIGINT using mappings
# Lowercase RHS Type: bigint
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> BIGINT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> BIGINT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: BIGINT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: BIGINT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 68
# length_compatible: True
#
# Processing RHS Index 40:
#   Field: ABC Indicator, Description: This is used to calculate "safety stock" and inventory accuracy.  This metric is used by the entire supply chain.  Classifies an article as an A, B, or C part according to its consumption value.  All article start out classified as “N” for new and are then re-evaluated for status change quarterly. , Type: BOOLEAN, Length: 299
#
# Normalizing RHS Type: BOOLEAN using mappings
# Lowercase RHS Type: boolean
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> BIT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> BIT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: BIT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: BIT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 299
# length_compatible: True
#
# Processing RHS Index 41:
#   Field: Wawa Proprietary, Description: Indicates whether item is proprietary to Wawa; Appliable for MSE - Indicates if the item is bought in only for wawa .(Applicable only for MSE - Dana Voss - 6/8/20), Type: TEXT, Length: 163
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# ...
#
# Processing RHS Index 438:
#   Field: Distributor retail value by  Pricelist for multiple DSD distributors, Description: Retail price retrived from each distributor , Type: TEXT, Length: 44
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 44
# length_compatible: True
#
# Processing RHS Index 439:
#   Field: Product friendly Serving  Size, Description: The serving available in the Item . (determins how many people does the product serve), Type: TEXT, Length: 86
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 86
# length_compatible: True
#
# Processing RHS Index 440:
#   Field: Product Selling Unit of measure (For FPC,OO,OG), Description: Selling UOM for the product by Wawa to customer. The product can be sold in multiple Uom (coke as a single or pack of 8) . Eg:
# EA , IP , Scoops , Spoodles , Oz , Lb , tray etc, Type: TEXT, Length: 176
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 176
# length_compatible: True
#
# Processing RHS Index 441:
#   Field: Retail price(S) by Price  list by vendor (DSD multi-distributors only), Description: Retail price retrived from each price list the product is associated to . The product will have same nuber of Retail prices as the price list linked to it.defined by Merch category .(Merch cat need to be filled first), Type: TEXT, Length: 217
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 217
# length_compatible: True
#
# Processing RHS Index 442:
#   Field: Base  Unit of measure for FPC , OO , OG, Description: Lowest unit of measure at which the item can be broken down.  For ingredient items, the standard portion for an item is converted into this BUOM.
# Eg: EA , FOZ, OZ, Type: TEXT, Length: 163
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 163
# length_compatible: True
#
# Processing RHS Index 443:
#   Field: Sellable Product  Indicator, Description: Defines if the sell side product is sellable, Type: BIGINT, Length: 44
#
# Normalizing RHS Type: BIGINT using mappings
# Lowercase RHS Type: bigint
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> BIGINT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> BIGINT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: BIGINT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: BIGINT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 44
# length_compatible: True
#
# Processing RHS Index 444:
#   Field: Item flavor, Description: flavor of the item, Type: TEXT, Length: 18
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 18
# length_compatible: True
#
# Processing RHS Index 445:
#   Field: Content Only  Indicator, Description: Flag to indicate Content Only when the supplier determines that an item needs to be set up, Type: TEXT, Length: 90
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 90
# length_compatible: True
#
# Processing RHS Index 446:
#   Field: Does this SAP Article have multipel suppliers (Blend/Subs), Description: Field to desigate if this item is sourced from multiple suppliers. , Type: TEXT, Length: 67
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 67
# length_compatible: True
#
# Processing RHS Index 447:
#   Field: MDM Status effective date for Item - Ingredient association, Description: The date from which the item - Ingredient association is valid, Type: BIGINT, Length: 62
#
# Normalizing RHS Type: BIGINT using mappings
# Lowercase RHS Type: bigint
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> BIGINT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> BIGINT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: BIGINT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: BIGINT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 62
# length_compatible: True
#
# Processing RHS Index 448:
#   Field: Ingredient Standard Portion Size Unit of Measure (UOM) QTY, Description: Determines the number / quantity of item Base UOM that goes into 1 standard portion  of the Item .(i.e. scoop, pinch, handful) . Portion can be same as BUOM., Type: INTEGER, Length: 157
#
# Normalizing RHS Type: INTEGER using mappings
# Lowercase RHS Type: integer
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> INT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> INT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: INT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: INT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 12, RHS Length: 157
# length_compatible: True
#
# Sorted Matches by Similarity Score:
# {
#   "results": [
#     {
#       "lhs_field_index": 5,
#       "lhs_field_name": "AENAM",
#       "lhs_field_description": "Name of Person Who Changed Object",
#       "lhs_field_data_type": "CHAR",
#       "normalized_lhs_type": "CHAR",
#       "lhs_field_length": 12,
#       "matches": [
#         {
#           "rank": 1,
#           "similarity_score": 0.7112370729446411,
#           "rhs_index": 63,
#           "rhs_field_name": "Item Name From Vendor",
#           "rhs_field_desc": "name of the item as represented by the seller / vendor",
#           "rhs_data_type": "VARCHAR",
#           "normalized_rhs_type": "VARCHAR",
#           "database_name": [
#             "pgsql_sql2023_map",
#             "saphana_sql2023_map"
#           ],
#           "rhs_length": 54,
#           "compatibility": "Compatible"
#         },
#         {
#           "rank": 2,
#           "similarity_score": 0.6646311283111572,
#           "rhs_index": 262,
#           "rhs_field_name": "WAWA Contact Name",
#           "rhs_field_desc": "The WAWA employee name acting as the primary contact for the item",
#           "rhs_data_type": "VARCHAR",
#           "normalized_rhs_type": "VARCHAR",
#           "database_name": [
#             "pgsql_sql2023_map",
#             "saphana_sql2023_map"
#           ],
#           "rhs_length": 65,
#           "compatibility": "Compatible"
#         },
#         {
#           "rank": 3,
#           "similarity_score": 0.6522256135940552,
#           "rhs_index": 182,
#           "rhs_field_name": "Sub Brand",
#           "rhs_field_desc": "Sub-brand name of the product.attribute managed by MCoE",
#           "rhs_data_type": "VARCHAR",
#           "normalized_rhs_type": "VARCHAR",
#           "database_name": [
#             "pgsql_sql2023_map",
#             "saphana_sql2023_map"
#           ],
#           "rhs_length": 55,
#           "compatibility": "Compatible"
#         },
#         {
#           "rank": 4,
#           "similarity_score": 0.6515486836433411,
#           "rhs_index": 274,
#           "rhs_field_name": "Product Information is Completed by - Name ",
#           "rhs_field_desc": "name and title of the supplier representative submitting the product information ",
#           "rhs_data_type": "VARCHAR",
#           "normalized_rhs_type": "VARCHAR",
#           "database_name": [
#             "pgsql_sql2023_map",
#             "saphana_sql2023_map"
#           ],
#           "rhs_length": 81,
#           "compatibility": "Compatible"
#         }
#       ]
#     }
#   ]
# }

# %% [markdown]
#                                                     Version-5

# %% [markdown]
# Version 5-
#
# ->  Added stats compatibility between the actual data from the columns names

# %%
import scipy.stats as stats
from scipy.stats import wasserstein_distance, ks_2samp
from sklearn.metrics import jaccard_score
from scipy.spatial.distance import euclidean
from sklearn.feature_extraction.text import CountVectorizer
from scipy.spatial.distance import jaccard

# %%
#df3 = pd.read_csv(r"/Users/rebeca.mendoza/Desktop/Data_Mapper/synthetic_lhs_data.csv")
#df4 = pd.read_csv(r"/Users/rebeca.mendoza/Desktop/Data_Mapper/synthetic_rhs_data.csv")

df3 = pd.read_csv(r"C:\Users\Yasvanth.Pamidi\OneDrive - ENCORA\Desktop\DataMap\synthetic data\synthetic_lhs_data.csv")
df4 = pd.read_csv(r"C:\Users\Yasvanth.Pamidi\OneDrive - ENCORA\Desktop\DataMap\synthetic data\synthetic_rhs_data.csv")

# %%
def convert_numeric_values(series):
    try:
        return pd.to_numeric(series, errors='coerce')
    except Exception as e:
        print(f"Conversion error: {e}")
        return series

def compute_statistical_similarity(lhs_col, rhs_col,dtype_category):
    """
    Determines if two data distributions are statistically similar based on their type.
    """
    similarity_score = 0
    
    lhs_values = lhs_col.dropna()
    rhs_values = rhs_col.dropna()
    
    if dtype_category in ["INT", "INTEGER", "BIGINT", "SMALLINT", "FLOAT", "DOUBLE", "REAL", "NUMERIC", "DECIMAL"]:
        # Compute Wasserstein distance
        lhs_values = convert_numeric_values(lhs_col.dropna())
        rhs_values = convert_numeric_values(rhs_col.dropna())
        
        if len(lhs_values) > 0 and len(rhs_values) > 0:
            wasserstein_dist = stats.wasserstein_distance(lhs_values, rhs_values)
            ks_stat, ks_p_value = stats.ks_2samp(lhs_values, rhs_values)
            similarity_score = 1 / (1 + wasserstein_dist) if wasserstein_dist > 0 else 1
            similarity_score = min(similarity_score, 1 - ks_stat)  # Normalize
        else:
            similarity_score = 0  # No valid comparison
    
    elif dtype_category in ["CHAR", "VARCHAR", "TEXT", "STRING", "JSON"]:
        # Categorical columns - use Jaccard Similarity
        
        print("Jaccard Similarity")
        lhs_values = lhs_col.dropna().astype(str).unique()
        rhs_values = rhs_col.dropna().astype(str).unique()
        
        if len(lhs_values) > 0 and len(rhs_values) > 0:
            vectorizer = CountVectorizer(preprocessor=lambda x: x, binary=True)
            matrix = vectorizer.fit_transform([' '.join(lhs_values), ' '.join(rhs_values)])
            similarity_score = 1 - jaccard(matrix.toarray()[0], matrix.toarray()[1])
        else:
            print("something happen")
            similarity_score = 0  # No valid comparison
    else:
        print("NOT WORK FOR THIS DATA TYPE")
        similarity_score = 0  # Incompatible types
    
    return similarity_score
  
  
def truncate_percentage(value):
    return f"{value:.2f}"

# %%
def retrieve_top_similar_sentences_json(selected_index, top_n, normalized_similarity_matrix, df1, df2, column1, column2, type_mapping, compatibilities, filter_compatible=True):
    
    """
    Retrieves the top similar sentences based on a similarity matrix while checking compatibility.

    Args:
        selected_index (int): Index of the LHS column to compare.
        top_n (int): Number of top matches to return.
        normalized_similarity_matrix (np.array): Precomputed similarity scores.
        df1 (pd.DataFrame): LHS dataset.
        df2 (pd.DataFrame): RHS dataset.
        column1 (str): Column name for description in LHS.
        column2 (str): Column name for description in RHS.
        type_mapping (dict): Mapping of data types.
        compatibilities (dict): Compatibility mapping.
        similarity_threshold (float): Minimum similarity score for a match.
        filter_compatible (bool, optional): Whether to filter only compatible matches. Defaults to True.

    Returns:
        dict: JSON output with matched results.
    """

    if normalized_similarity_matrix.shape != (len(df1), len(df2)):

        print(f"Error: Similarity matrix shape {normalized_similarity_matrix.shape} does not match dataframes: LHS {len(df1)}, RHS {len(df2)}")
        raise ValueError("The similarity matrix dimensions must match the LHS and RHS datasets.")
    
    print("Input validation passed. Processing similarity matches...")

    similarities = normalized_similarity_matrix[selected_index]
    matches = []

    normalized_lhs_type = None
    stat_similarity = 0

    for idx in range(len(similarities)):
        similarity_score = float(similarities[idx])  # Extract similarity score
        if similarity_score < similarity_threshold:
            continue  # Skip if below threshold
        similarity_score_truncated = truncate_percentage(similarity_score * 100)

        rhs_field = df2.loc[idx, 'Attribute']
        rhs_desc = df2.loc[idx, column2]
        rhs_type = df2.loc[idx, 'Data_Type']
        rhs_length = df2.loc[idx, 'Length'] # RHS length

        print(f"\nProcessing RHS Index {idx}:")
        print(f"  Field: {rhs_field}, Description: {rhs_desc}, Type: {rhs_type}, Length: {rhs_length}")

        database_context = df2.loc[idx, 'Database'] if 'Database' in df2.columns else "default_database"
        normalized_rhs_type, database_context = normalize_data_type(rhs_type, None, type_mapping)

        print(f"  Normalized RHS Type: {normalized_rhs_type}, Database Context: {database_context}")

        lhs_type = df1.loc[selected_index, 'Data_Type'].upper()
        lhs_length = df1.loc[selected_index, 'Length']  # LHS length
        lhs_field = df1.loc[selected_index, 'Field Name']
        normalized_lhs_type, _ = normalize_data_type(lhs_type, None, type_mapping)

        print(f"  LHS Type: {lhs_type}, Normalized LHS Type: {normalized_lhs_type}")

        normalized_rhs_type = normalized_rhs_type.upper()
        is_compatible = are_compatible(lhs_type, normalized_rhs_type, compatibilities)

        # Normalize length before checking compatibility
        #lhs_length = normalize_length(lhs_length)
        #rhs_length = normalize_length(rhs_length)

        length_compatible = is_length_compatible(lhs_length, rhs_length, check_length=True)
        
        print(f"length_compatible: {length_compatible}")
        
        if lhs_field in df3.columns and rhs_field in df4.columns:
            print(f"Statistical Similarity: {lhs_field} vs {rhs_field}")
            lhs_col = df3[lhs_field]
            rhs_col = df4[rhs_field]
            
            if(is_compatible):
                stat_similarity = compute_statistical_similarity(lhs_col, rhs_col, normalized_rhs_type)
        else:
            stat_similarity = 0  # Incompatible types
        print(f"Statistical Similarity Score: {stat_similarity}")
        stat_similarity_percentage = truncate_percentage(stat_similarity * 100)

        
        if is_compatible and length_compatible and stat_similarity >= 0.3:
            matches.append({
                "rank": None,  # Placeholder to set rank later
                "similarity_score": similarity_score_truncated,
                "rhs_index": int(df2.index[idx]),
                "rhs_field_name": rhs_field,
                "rhs_field_desc": rhs_desc,
                "rhs_data_type": rhs_type,
                "normalized_rhs_type": normalized_rhs_type,
                "database_name": database_context if database_context else "Unknown",
                "rhs_length": convert_to_native_type(rhs_length),
                "compatibility": "Compatible",
                "statistical_similarity": stat_similarity_percentage  
            })

    # Sort matches by similarity score (descending)
    matches = sorted(matches, key=lambda x: x["similarity_score"], reverse=True)[:top_n]

    print("\nSorted Matches by Similarity Score:")

    for rank, match in enumerate(matches, start=1):
        match["rank"] = rank

    if not matches:
        matches.append({"message": "No compatible matches found."})

    # Fetch LHS details safely
    lhs_field = df1.loc[selected_index,'Field Name']
    lhs_desc = df1.loc[selected_index, column1]
    lhs_type = df1.loc[selected_index, 'Data_Type']
    lhs_length = df1.loc[selected_index, 'Length']   

    result = {
        "lhs_field_index": selected_index,
        "lhs_field_name": lhs_field,
        "lhs_field_description": lhs_desc,
        "lhs_field_data_type": lhs_type,
        "normalized_lhs_type": normalized_lhs_type,
        "lhs_field_length": convert_to_native_type(lhs_length),  
        "matches": matches
    }

    return {"results": [result]}

# Load type mappings and compatibilities
type_mapping = load_mappings(mappings_dir)
compatibilities_file = os.path.join(mappings_dir, 'compatibilities.json')
compatibilities = load_compatibilities(compatibilities_file)


# User Input with Validations

# Validate LHS Index
while True:
    try:
        enter_index = int(input("Enter the index from LHS to process: "))
        if 0<= enter_index <len(df1): # Ensure it's within range
            break
        else:
            print(f"Error: Index out of range. Please enter a value between 0 and {len(df1) - 1}.")
    except ValueError:
        print("Invalid input. Please enter a valid integer.")


# Validate Top N
while True:
    try:
        top_n = int(input("Enter the number of top similar sentences to retrieve (N): ") or 3)
        if top_n > 0:
            break
        else:
            print("Error: Please enter a positive integer greater than 0.")
    except ValueError:
        print("Invalid input. Please enter a valid integer.")

# Validate Similarity Score Threshold
while True:
    try:
        similarity_threshold = float(input("Enter the similarity score threshold (0.0 - 1.0): "))
        if 0.0 <= similarity_threshold <= 1.0:
            break
        else:
            print("Error: Please enter a value between 0.0 and 1.0.")
    except ValueError:
        print("Invalid input. Please enter a numeric value between 0.0 and 1.0.")

output_json = retrieve_top_similar_sentences_json(
    enter_index, top_n, normalized_similarity_matrix, df1, df2, "Description", "Description", type_mapping, compatibilities,similarity_threshold)
print(json.dumps(output_json, indent=2))
# Out:
# Loading mappings from directory: C:\Users\Yasvanth.Pamidi\OneDrive - ENCORA\Desktop\VSC\DataMapper\versions\mappings
# Processing file: pgsql_sql2023_map.json as database: pgsql_sql2023_map
# Loaded mapping for pgsql_sql2023_map: {'VARCHAR': 'VARCHAR', 'CHAR': 'CHAR', 'TEXT': 'VARCHAR(max)', 'BOOLEAN': 'BIT', 'SMALLINT': 'SMALLINT', 'INTEGER': 'INT', 'BIGINT': 'BIGINT', 'NUMERIC': 'NUMERIC', 'DECIMAL': 'DECIMAL', 'REAL': 'REAL', 'DOUBLE PRECISION': 'FLOAT', 'DATE': 'DATE', 'TIME': 'TIME', 'TIMESTAMP': 'TIMESTAMP', 'TIMESTAMPTZ': 'TIMESTAMP WITH TIME ZONE', 'JSON': 'JSON', 'JSONB': 'JSON', 'UUID': 'UNIQUEIDENTIFIER', 'BYTEA': 'VARBINARY(max)', 'ARRAY': 'ARRAY', 'XML': 'XML', 'CITEXT': 'VARCHAR'}
# Processing file: saphana_sql2023_map.json as database: saphana_sql2023_map
# Loaded mapping for saphana_sql2023_map: {'NVARCHAR': 'NVARCHAR', 'VARCHAR': 'VARCHAR', 'CHAR': 'CHAR', 'DATE': 'DATE', 'TIME': 'TIME', 'SECONDDATE': 'DATETIME2', 'TIMESTAMP': 'TIMESTAMP', 'DECIMAL': 'DECIMAL', 'SMALLINT': 'SMALLINT', 'INTEGER': 'INT', 'BIGINT': 'BIGINT', 'FLOAT': 'FLOAT', 'REAL': 'REAL', 'DOUBLE': 'FLOAT', 'CLOB': 'VARCHAR(max)', 'NCLOB': 'NVARCHAR(max)', 'BLOB': 'VARBINARY(max)', 'BOOLEAN': 'BIT', 'ST_GEOMETRY': 'JSON', 'ST_POINT': 'JSON', 'JSON': 'JSON', 'GUID': 'UNIQUEIDENTIFIER', 'TINYINT': 'SMALLINT'}
# Processing file: sapmara_sql2023_map.json as database: sapmara_sql2023_map
# Loaded mapping for sapmara_sql2023_map: {'clnt': 'VARCHAR', 'char': 'CHAR', 'dats': 'DATE', 'unit': 'VARCHAR', 'numc': 'NUMERIC', 'quan': 'FLOAT', 'dec': 'DECIMAL', 'int2': 'SMALLINT', 'int4': 'INT', 'curr': 'DECIMAL', 'flag': 'BIT', 'uuid': 'UNIQUEIDENTIFIER', 'bin': 'VARBINARY', 'json': 'JSON', 'time': 'TIME', 'timestamp': 'TIMESTAMP'}
# Mappings loaded successfully: {'pgsql_sql2023_map': {'VARCHAR': 'VARCHAR', 'CHAR': 'CHAR', 'TEXT': 'VARCHAR(max)', 'BOOLEAN': 'BIT', 'SMALLINT': 'SMALLINT', 'INTEGER': 'INT', 'BIGINT': 'BIGINT', 'NUMERIC': 'NUMERIC', 'DECIMAL': 'DECIMAL', 'REAL': 'REAL', 'DOUBLE PRECISION': 'FLOAT', 'DATE': 'DATE', 'TIME': 'TIME', 'TIMESTAMP': 'TIMESTAMP', 'TIMESTAMPTZ': 'TIMESTAMP WITH TIME ZONE', 'JSON': 'JSON', 'JSONB': 'JSON', 'UUID': 'UNIQUEIDENTIFIER', 'BYTEA': 'VARBINARY(max)', 'ARRAY': 'ARRAY', 'XML': 'XML', 'CITEXT': 'VARCHAR'}, 'saphana_sql2023_map': {'NVARCHAR': 'NVARCHAR', 'VARCHAR': 'VARCHAR', 'CHAR': 'CHAR', 'DATE': 'DATE', 'TIME': 'TIME', 'SECONDDATE': 'DATETIME2', 'TIMESTAMP': 'TIMESTAMP', 'DECIMAL': 'DECIMAL', 'SMALLINT': 'SMALLINT', 'INTEGER': 'INT', 'BIGINT': 'BIGINT', 'FLOAT': 'FLOAT', 'REAL': 'REAL', 'DOUBLE': 'FLOAT', 'CLOB': 'VARCHAR(max)', 'NCLOB': 'NVARCHAR(max)', 'BLOB': 'VARBINARY(max)', 'BOOLEAN': 'BIT', 'ST_GEOMETRY': 'JSON', 'ST_POINT': 'JSON', 'JSON': 'JSON', 'GUID': 'UNIQUEIDENTIFIER', 'TINYINT': 'SMALLINT'}, 'sapmara_sql2023_map': {'clnt': 'VARCHAR', 'char': 'CHAR', 'dats': 'DATE', 'unit': 'VARCHAR', 'numc': 'NUMERIC', 'quan': 'FLOAT', 'dec': 'DECIMAL', 'int2': 'SMALLINT', 'int4': 'INT', 'curr': 'DECIMAL', 'flag': 'BIT', 'uuid': 'UNIQUEIDENTIFIER', 'bin': 'VARBINARY', 'json': 'JSON', 'time': 'TIME', 'timestamp': 'TIMESTAMP'}}
# Input validation passed. Processing similarity matches...
#
# Processing RHS Index 0:
#   Field: Shipper Contents Name, Description: Items that make up the shipper display  (i.e. M&Ms 3 flavor shipper display), Type: TEXT, Length: 76
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 76
# length_compatible: True
# Statistical Similarity: BBTYP vs Shipper Contents Name
# NOT WORK FOR THIS DATA TYPE
# Statistical Similarity Score: 0
#
# Processing RHS Index 1:
#   Field: Shipper Contents Qty , Description: The quantity of each component item in a shipper display, Type: INTEGER, Length: 56
#
# Normalizing RHS Type: INTEGER using mappings
# Lowercase RHS Type: integer
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> INT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> INT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: INT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: INT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 56
# length_compatible: True
# Statistical Similarity: BBTYP vs Shipper Contents Qty
# Statistical Similarity Score: 0
#
# Processing RHS Index 2:
#   Field: Variety, Description: Variety of item, as defined by the MCoE at sub-category level. Attribute managed by MCoE, Type: VARCHAR, Length: 88
#
# Normalizing RHS Type: VARCHAR using mappings
# Lowercase RHS Type: varchar
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> VARCHAR
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: VARCHAR, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 88
# length_compatible: True
# Statistical Similarity: BBTYP vs Variety
# Jaccard Similarity
# Statistical Similarity Score: 0.5783664459161149
#
# Processing RHS Index 3:
#   Field: GR Processing Time in days, Description: The time between the delivery or the production of a product and its availability in stores  (in days), Type: FLOAT, Length: 102
#
# Normalizing RHS Type: FLOAT using mappings
# Lowercase RHS Type: float
# Checking database: pgsql_sql2023_map
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> FLOAT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: FLOAT, Matching Databases: ['saphana_sql2023_map']
#   Normalized RHS Type: FLOAT, Database Context: ['saphana_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 102
# length_compatible: True
# Statistical Similarity: BBTYP vs GR Processing Time in days
# Statistical Similarity Score: 0.5783664459161149
#
# Processing RHS Index 4:
#   Field: SAP Global Article Status, Description: The cross-plant material status restricts the usability of the material for all plants, that is, it defines whether a warning or error message is displayed if you include the material in a particular function. Defualts to Active on set up ; going forward the cat team will use htis attribute to de-active an item, Type: BOOLEAN, Length: 312
#
# Normalizing RHS Type: BOOLEAN using mappings
# Lowercase RHS Type: boolean
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> BIT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> BIT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: BIT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: BIT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 312
# length_compatible: True
# Statistical Similarity: BBTYP vs SAP Global Article Status
# Statistical Similarity Score: 0.5783664459161149
#
# Processing RHS Index 5:
#   Field: Serve Temperature, Description: temperature of the product, Type: TEXT, Length: 26
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 26
# length_compatible: True
# Statistical Similarity: BBTYP vs Serve Temperature
# NOT WORK FOR THIS DATA TYPE
# Statistical Similarity Score: 0
#
# Processing RHS Index 6:
#   Field: MDM Status effective date, Description: The date from which the article status is effective, Type: BOOLEAN, Length: 51
#
# Normalizing RHS Type: BOOLEAN using mappings
# Lowercase RHS Type: boolean
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> BIT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> BIT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: BIT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: BIT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 51
# length_compatible: True
# Statistical Similarity: BBTYP vs MDM Status effective date
# Statistical Similarity Score: 0
#
# Processing RHS Index 7:
#   Field: Seasonal indicator, Description: Indicates whether the product is sold seasonally or every day, Type: TEXT, Length: 61
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 61
# length_compatible: True
# Statistical Similarity: BBTYP vs Seasonal indicator
# NOT WORK FOR THIS DATA TYPE
# Statistical Similarity Score: 0
#
# Processing RHS Index 8:
#   Field: F&R exception messages (Other Wawa Specific Data in SAP), Description: Used by F&R system to process exception messages used for inventory accuracy by stores, Type: TEXT, Length: 86
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 86
# length_compatible: True
# Statistical Similarity: BBTYP vs F&R exception messages (Other Wawa Specific Data in SAP)
# NOT WORK FOR THIS DATA TYPE
# Statistical Similarity Score: 0
#
# Processing RHS Index 9:
#   Field: Labor Scheduler Code, Description: Used for labor scheduler to put away deliveries, Type: TEXT, Length: 47
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 47
# length_compatible: True
# Statistical Similarity: BBTYP vs Labor Scheduler Code
# NOT WORK FOR THIS DATA TYPE
# Statistical Similarity Score: 0
#
# Processing RHS Index 10:
#   Field: Item Type (WBC Reporting), Description: nan, Type: TEXT, Length: 3
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 3
# length_compatible: True
# Statistical Similarity: BBTYP vs Item Type (WBC Reporting)
# NOT WORK FOR THIS DATA TYPE
# Statistical Similarity Score: 0
#
# Processing RHS Index 11:
#   Field: SAP Article Status Validity Date (System entered date), Description: The valid-from date of the material status is considered only if it precedes or is the same as the planning date. This denotes the sell end date of the Item/ingredient/product, Type: BOOLEAN, Length: 175
#
# Normalizing RHS Type: BOOLEAN using mappings
# Lowercase RHS Type: boolean
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> BIT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> BIT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: BIT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: BIT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 175
# length_compatible: True
# Statistical Similarity: BBTYP vs SAP Article Status Validity Date (System entered date)
# Statistical Similarity Score: 0
#
# Processing RHS Index 12:
#   Field: External Merchandise Category, Description: SAP is External Material Group.  External Merchandise Category links the inventory from one article to another.  This process occurs in the nightly runs. There are defined groups of articles that this is maintained on: Bakery, Coffee and blends), Type: TEXT, Length: 245
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 245
# length_compatible: True
# Statistical Similarity: BBTYP vs External Merchandise Category
# NOT WORK FOR THIS DATA TYPE
# Statistical Similarity Score: 0
#
# Processing RHS Index 13:
#   Field: Pct (% ) Juice, Description: % of each type of juice in product (Tax??), Type: TEXT, Length: 42
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 42
# length_compatible: True
# Statistical Similarity: BBTYP vs Pct (% ) Juice
# NOT WORK FOR THIS DATA TYPE
# Statistical Similarity Score: 0
#
# Processing RHS Index 15:
#   Field: Is this product Vegan?, Description: products do not contain ingredients of meat, fish, fowl, animal by-products, eggs or egg products, milk or milk products, honey or honey bee products. Involve no animal testing of ingredients by supplier, producer, manufacturer or independent party. , Type: TEXT, Length: 250
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 250
# length_compatible: True
# Statistical Similarity: BBTYP vs Is this product Vegan?
# NOT WORK FOR THIS DATA TYPE
# Statistical Similarity Score: 0
#
# Processing RHS Index 17:
#   Field: Is this product Kosher? , Description: Kosher , Type: TEXT, Length: 7
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 7
# length_compatible: True
# Statistical Similarity: BBTYP vs Is this product Kosher?
# NOT WORK FOR THIS DATA TYPE
# Statistical Similarity Score: 0
#
# Processing RHS Index 19:
#   Field: USDA grade , Description: USDA grade , Type: TEXT, Length: 11
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 11
# length_compatible: True
# Statistical Similarity: BBTYP vs USDA grade
# NOT WORK FOR THIS DATA TYPE
# Statistical Similarity Score: 0
#
# Processing RHS Index 20:
#   Field: Is this product certified organic, Description: Organic, Type: TEXT, Length: 7
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 7
# length_compatible: True
# Statistical Similarity: BBTYP vs Is this product certified organic
# NOT WORK FOR THIS DATA TYPE
# Statistical Similarity Score: 0
#
# Processing RHS Index 21:
#   Field: manufacturer suggested MSRP, Description: Sugested MSRP from manufacturer, Type: TEXT, Length: 31
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 31
# length_compatible: True
# Statistical Similarity: BBTYP vs manufacturer suggested MSRP
# NOT WORK FOR THIS DATA TYPE
# Statistical Similarity Score: 0
#
# Processing RHS Index 22:
#   Field: Master case cost, Description: Cost to the distributor or store for the master case; (Applicable for Tobacco also), Type: TEXT, Length: 83
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 83
# length_compatible: True
# Statistical Similarity: BBTYP vs Master case cost
# NOT WORK FOR THIS DATA TYPE
# Statistical Similarity Score: 0
#
# Processing RHS Index 23:
#   Field: IP  cost, Description: Cost to the distributor or store for the inner pack, Type: TEXT, Length: 51
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 51
# length_compatible: True
# Statistical Similarity: BBTYP vs IP  cost
# NOT WORK FOR THIS DATA TYPE
# Statistical Similarity Score: 0
#
# Processing RHS Index 24:
#   Field: Unit (EA) cost, Description: Cost to the distributor or store for the each, Type: TEXT, Length: 45
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 45
# length_compatible: True
# Statistical Similarity: BBTYP vs Unit (EA) cost
# NOT WORK FOR THIS DATA TYPE
# Statistical Similarity Score: 0
#
# Processing RHS Index 25:
#   Field: Shipper contents unit cost, Description: The cost of each of the contents of a shipper display, Type: TEXT, Length: 53
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 53
# length_compatible: True
# Statistical Similarity: BBTYP vs Shipper contents unit cost
# NOT WORK FOR THIS DATA TYPE
# Statistical Similarity Score: 0
#
# Processing RHS Index 27:
#   Field: add on flag
# Variable Load Fee (Gift Cards) ?, Description: Additional fee charged to a gift card customer to activate the card. Gift cards with variable retails have added service fees.  The variable load fee box on the NIF tells us which fee to assign using the add on field in SAP., Type: TEXT, Length: 224
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 224
# length_compatible: True
# Statistical Similarity: BBTYP vs add on flag
# Variable Load Fee (Gift Cards) ?
# NOT WORK FOR THIS DATA TYPE
# Statistical Similarity Score: 0
#
# Processing RHS Index 28:
#   Field: Cost -label Charge, Description: The additional cost added to an item for a label - FL only.
# Currenty added to PB00 ; does not show up as a separate cost condition today, Type: TEXT, Length: 136
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 136
# length_compatible: True
# Statistical Similarity: BBTYP vs Cost -label Charge
# NOT WORK FOR THIS DATA TYPE
# Statistical Similarity Score: 0
#
# Processing RHS Index 29:
#   Field: Tobacco Carton Cost ?, Description: nan, Type: TEXT, Length: 3
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 3
# length_compatible: True
# Statistical Similarity: BBTYP vs Tobacco Carton Cost ?
# NOT WORK FOR THIS DATA TYPE
# Statistical Similarity Score: 0
#
# Processing RHS Index 30:
#   Field: Tobacco SSOI ?, Description: State Specific Off Invoice amount, Type: TEXT, Length: 33
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 33
# length_compatible: True
# Statistical Similarity: BBTYP vs Tobacco SSOI ?
# NOT WORK FOR THIS DATA TYPE
# Statistical Similarity Score: 0
#
# Processing RHS Index 31:
#   Field: FL Transfer truck Indicator, Description: Indicates whether the item needs to be transported on a truck from MA to FL ; transfer between WBC / NJDC  to MSE , Type: TEXT, Length: 114
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 114
# length_compatible: True
# Statistical Similarity: BBTYP vs FL Transfer truck Indicator
# NOT WORK FOR THIS DATA TYPE
# Statistical Similarity Score: 0
#
# Processing RHS Index 32:
#   Field: Cost Eff Start date, Description: Effective Start date, Type: TEXT, Length: 20
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 20
# length_compatible: True
# Statistical Similarity: BBTYP vs Cost Eff Start date
# NOT WORK FOR THIS DATA TYPE
# Statistical Similarity Score: 0
#
# Processing RHS Index 33:
#   Field: Cost Eff End date, Description: Effective End  date, Type: TEXT, Length: 19
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 19
# length_compatible: True
# Statistical Similarity: BBTYP vs Cost Eff End date
# NOT WORK FOR THIS DATA TYPE
# Statistical Similarity Score: 0
#
# Processing RHS Index 34:
#   Field: Purchasing Bracket, Description: The price bracketin which the distributor typically purchases from the manufacturer based on quantity, Type: INTEGER, Length: 101
#
# Normalizing RHS Type: INTEGER using mappings
# Lowercase RHS Type: integer
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> INT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> INT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: INT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: INT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 101
# length_compatible: True
# Statistical Similarity: BBTYP vs Purchasing Bracket
# Statistical Similarity Score: 0
#
# Processing RHS Index 35:
#   Field: Cycle count category, Description: Drives Operational process for Cycle Counts within the Stores ; Interface with Cycle count system/Refernce data system for list of reference values for this category , Type: TEXT, Length: 166
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 166
# length_compatible: True
# Statistical Similarity: BBTYP vs Cycle count category
# NOT WORK FOR THIS DATA TYPE
# Statistical Similarity Score: 0
#
# Processing RHS Index 36:
#   Field: Equipment Name, Description: Name of the equipment; (RACI is different ), Type: VARCHAR, Length: 43
#
# Normalizing RHS Type: VARCHAR using mappings
# Lowercase RHS Type: varchar
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> VARCHAR
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: VARCHAR, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 43
# length_compatible: True
# Statistical Similarity: BBTYP vs Equipment Name
# Jaccard Similarity
# Statistical Similarity Score: 0.5861875350926447
#
# Processing RHS Index 37:
#   Field: Equipment Model, Description: Equipment model number from the manufacturer, Type: BIGINT, Length: 44
#
# Normalizing RHS Type: BIGINT using mappings
# Lowercase RHS Type: bigint
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> BIGINT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> BIGINT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: BIGINT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: BIGINT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 44
# length_compatible: True
# Statistical Similarity: BBTYP vs Equipment Model
# Statistical Similarity Score: 0.5861875350926447
#
# Processing RHS Index 38:
#   Field: Equipment Eff Start date, Description: Effective Start date, Type: TEXT, Length: 20
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# ...
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 217
# length_compatible: True
# Statistical Similarity: BBTYP vs Retail price(S) by Price  list by vendor (DSD multi-distributors only)
# NOT WORK FOR THIS DATA TYPE
# Statistical Similarity Score: 0
#
# Processing RHS Index 442:
#   Field: Base  Unit of measure for FPC , OO , OG, Description: Lowest unit of measure at which the item can be broken down.  For ingredient items, the standard portion for an item is converted into this BUOM.
# Eg: EA , FOZ, OZ, Type: TEXT, Length: 163
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 163
# length_compatible: True
# Statistical Similarity: BBTYP vs Base  Unit of measure for FPC , OO , OG
# NOT WORK FOR THIS DATA TYPE
# Statistical Similarity Score: 0
#
# Processing RHS Index 443:
#   Field: Sellable Product  Indicator, Description: Defines if the sell side product is sellable, Type: BIGINT, Length: 44
#
# Normalizing RHS Type: BIGINT using mappings
# Lowercase RHS Type: bigint
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> BIGINT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> BIGINT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: BIGINT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: BIGINT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 44
# length_compatible: True
# Statistical Similarity: BBTYP vs Sellable Product  Indicator
# Statistical Similarity Score: 0
#
# Processing RHS Index 444:
#   Field: Item flavor, Description: flavor of the item, Type: TEXT, Length: 18
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 18
# length_compatible: True
# Statistical Similarity: BBTYP vs Item flavor
# NOT WORK FOR THIS DATA TYPE
# Statistical Similarity Score: 0
#
# Processing RHS Index 445:
#   Field: Content Only  Indicator, Description: Flag to indicate Content Only when the supplier determines that an item needs to be set up, Type: TEXT, Length: 90
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 90
# length_compatible: True
# Statistical Similarity: BBTYP vs Content Only  Indicator
# NOT WORK FOR THIS DATA TYPE
# Statistical Similarity Score: 0
#
# Processing RHS Index 446:
#   Field: Does this SAP Article have multipel suppliers (Blend/Subs), Description: Field to desigate if this item is sourced from multiple suppliers. , Type: TEXT, Length: 67
#
# Normalizing RHS Type: TEXT using mappings
# Lowercase RHS Type: text
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> VARCHAR(max)
# Checking database: saphana_sql2023_map
# Checking database: sapmara_sql2023_map
# Final Normalized Type: VARCHAR(max), Matching Databases: ['pgsql_sql2023_map']
#   Normalized RHS Type: VARCHAR(max), Database Context: ['pgsql_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 67
# length_compatible: True
# Statistical Similarity: BBTYP vs Does this SAP Article have multipel suppliers (Blend/Subs)
# NOT WORK FOR THIS DATA TYPE
# Statistical Similarity Score: 0
#
# Processing RHS Index 447:
#   Field: MDM Status effective date for Item - Ingredient association, Description: The date from which the item - Ingredient association is valid, Type: BIGINT, Length: 62
#
# Normalizing RHS Type: BIGINT using mappings
# Lowercase RHS Type: bigint
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> BIGINT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> BIGINT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: BIGINT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: BIGINT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 62
# length_compatible: True
# Statistical Similarity: BBTYP vs MDM Status effective date for Item - Ingredient association
# Statistical Similarity Score: 0
#
# Processing RHS Index 448:
#   Field: Ingredient Standard Portion Size Unit of Measure (UOM) QTY, Description: Determines the number / quantity of item Base UOM that goes into 1 standard portion  of the Item .(i.e. scoop, pinch, handful) . Portion can be same as BUOM., Type: INTEGER, Length: 157
#
# Normalizing RHS Type: INTEGER using mappings
# Lowercase RHS Type: integer
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> INT
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> INT
# Checking database: sapmara_sql2023_map
# Final Normalized Type: INT, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#   Normalized RHS Type: INT, Database Context: ['pgsql_sql2023_map', 'saphana_sql2023_map']
#
# Normalizing RHS Type: CHAR using mappings
# Lowercase RHS Type: char
# Checking database: pgsql_sql2023_map
# Match found in pgsql_sql2023_map: Normalized Type -> CHAR
# Checking database: saphana_sql2023_map
# Match found in saphana_sql2023_map: Normalized Type -> CHAR
# Checking database: sapmara_sql2023_map
# Match found in sapmara_sql2023_map: Normalized Type -> CHAR
# Final Normalized Type: CHAR, Matching Databases: ['pgsql_sql2023_map', 'saphana_sql2023_map', 'sapmara_sql2023_map']
#   LHS Type: CHAR, Normalized LHS Type: CHAR
# LHS Length: 1, RHS Length: 157
# length_compatible: True
# Statistical Similarity: BBTYP vs Ingredient Standard Portion Size Unit of Measure (UOM) QTY
# Statistical Similarity Score: 0
#
# Sorted Matches by Similarity Score:
# {
#   "results": [
#     {
#       "lhs_field_index": 128,
#       "lhs_field_name": "BBTYP",
#       "lhs_field_description": "Assortment List Type",
#       "lhs_field_data_type": "CHAR",
#       "normalized_lhs_type": "CHAR",
#       "lhs_field_length": 1,
#       "matches": [
#         {
#           "rank": 1,
#           "similarity_score": "69.33",
#           "rhs_index": 2,
#           "rhs_field_name": "Variety",
#           "rhs_field_desc": "Variety of item, as defined by the MCoE at sub-category level. Attribute managed by MCoE",
#           "rhs_data_type": "VARCHAR",
#           "normalized_rhs_type": "VARCHAR",
#           "database_name": [
#             "pgsql_sql2023_map",
#             "saphana_sql2023_map"
#           ],
#           "rhs_length": 88,
#           "compatibility": "Compatible",
#           "statistical_similarity": "57.84"
#         },
#         {
#           "rank": 2,
#           "similarity_score": "67.82",
#           "rhs_index": 95,
#           "rhs_field_name": "Category name - Sub category",
#           "rhs_field_desc": "Name of classification. E.g.:\n1.  Sub Category",
#           "rhs_data_type": "VARCHAR",
#           "normalized_rhs_type": "VARCHAR",
#           "database_name": [
#             "pgsql_sql2023_map",
#             "saphana_sql2023_map"
#           ],
#           "rhs_length": 46,
#           "compatibility": "Compatible",
#           "statistical_similarity": "56.40"
#         },
#         {
#           "rank": 3,
#           "similarity_score": "67.40",
#           "rhs_index": 107,
#           "rhs_field_name": "Ingredient  Name in OS",
#           "rhs_field_desc": "Ingredient name used in the Option set",
#           "rhs_data_type": "VARCHAR",
#           "normalized_rhs_type": "VARCHAR",
#           "database_name": [
#             "pgsql_sql2023_map",
#             "saphana_sql2023_map"
#           ],
#           "rhs_length": 38,
#           "compatibility": "Compatible",
#           "statistical_similarity": "57.68"
#         },
#         {
#           "rank": 4,
#           "similarity_score": "66.59",
#           "rhs_index": 117,
#           "rhs_field_name": "Option Set Long  Name",
#           "rhs_field_desc": "Name of the option set ; Associate facing",
#           "rhs_data_type": "VARCHAR",
#           "normalized_rhs_type": "VARCHAR",
#           "database_name": [
#             "pgsql_sql2023_map",
#             "saphana_sql2023_map"
#           ],
#           "rhs_length": 41,
#           "compatibility": "Compatible",
#           "statistical_similarity": "58.21"
#         },
#         {
#           "rank": 5,
#           "similarity_score": "66.33",
#           "rhs_index": 256,
#           "rhs_field_name": "Sorter  Name",
#           "rhs_field_desc": "Name of  the company that sorts the ingredients / Products . Applicable only for Cross DOC . Refer to Cross Doc summary for addn details",
#           "rhs_data_type": "VARCHAR",
#           "normalized_rhs_type": "VARCHAR",
#           "database_name": [
#             "pgsql_sql2023_map",
#             "saphana_sql2023_map"
#           ],
#           "rhs_length": 136,
#           "compatibility": "Compatible",
#           "statistical_similarity": "59.12"
#         },
#         {
#           "rank": 6,
#           "similarity_score": "65.36",
#           "rhs_index": 99,
#           "rhs_field_name": "Price Family code (tobacco)",
#           "rhs_field_desc": "Name of classification. E.g.:\n1 Family code(tobacco)",
#           "rhs_data_type": "VARCHAR",
#           "normalized_rhs_type": "VARCHAR",
#           "database_name": [
#             "pgsql_sql2023_map",
#             "saphana_sql2023_map"
#           ],
#           "rhs_length": 52,
#           "compatibility": "Compatible",
#           "statistical_similarity": "57.41"
#         },
#         {
#           "rank": 7,
#           "similarity_score": "65.33",
#           "rhs_index": 63,
#           "rhs_field_name": "Item Name From Vendor",
#           "rhs_field_desc": "name of the item as represented by the seller / vendor",
#           "rhs_data_type": "VARCHAR",
#           "normalized_rhs_type": "VARCHAR",
#           "database_name": [
#             "pgsql_sql2023_map",
#             "saphana_sql2023_map"
#           ],
#           "rhs_length": 54,
#           "compatibility": "Compatible",
#           "statistical_similarity": "56.44"
#         },
#         {
#           "rank": 8,
#           "similarity_score": "63.36",
#           "rhs_index": 250,
#           "rhs_field_name": "friendly size ",
#           "rhs_field_desc": "frienly name for size ; Family / Singel serve size",
#           "rhs_data_type": "VARCHAR",
#           "normalized_rhs_type": "VARCHAR",
#           "database_name": [
#             "pgsql_sql2023_map",
#             "saphana_sql2023_map"
#           ],
#           "rhs_length": 50,
#           "compatibility": "Compatible",
#           "statistical_similarity": "57.66"
#         },
#         {
#           "rank": 9,
#           "similarity_score": "62.89",
#           "rhs_index": 64,
#           "rhs_field_name": "Item Long Name",
#           "rhs_field_desc": "Standardized name of the item as represented in MDM",
#           "rhs_data_type": "VARCHAR",
#           "normalized_rhs_type": "VARCHAR",
#           "database_name": [
#             "pgsql_sql2023_map",
#             "saphana_sql2023_map"
#           ],
#           "rhs_length": 51,
#           "compatibility": "Compatible",
#           "statistical_similarity": "57.37"
#         },
#         {
#           "rank": 10,
#           "similarity_score": "62.89",
#           "rhs_index": 105,
#           "rhs_field_name": "Ingredient Long Name",
#           "rhs_field_desc": "Standardized name of the item as represented in MDM",
#           "rhs_data_type": "VARCHAR",
#           "normalized_rhs_type": "VARCHAR",
#           "database_name": [
#             "pgsql_sql2023_map",
#             "saphana_sql2023_map"
#           ],
#           "rhs_length": 51,
#           "compatibility": "Compatible",
#           "statistical_similarity": "54.15"
#         }
#       ]
#     }
#   ]
# }

# %%
import pandas as pd
import IPython.display as display


# Load data into DataFrames
lhs_df = df3
rhs_df = df4

# Define columns of interest
lhs_column = output_json["results"][0]["lhs_field_name"]
rhs_columns = [match["rhs_field_name"] for match in output_json["results"][0]["matches"]]

# Extract relevant columns
lhs_data = lhs_df[[lhs_column]]
rhs_data = rhs_df[rhs_columns]

# Generate summary statistics
summary_stats = pd.DataFrame(columns=["Column", "Null Values", "Distinct Values", "Non-Distinct Values", "Most Common Value", "Mean Length", "Min Length", "Max Length"])

for col in [lhs_column] + rhs_columns:
    null_values = lhs_df[col].isnull().sum() if col == lhs_column else rhs_df[col].isnull().sum()
    distinct_values = lhs_df[col].nunique() if col == lhs_column else rhs_df[col].nunique()
    total_values = len(lhs_df[col]) if col == lhs_column else len(rhs_df[col])
    non_distinct_values = total_values - distinct_values
    most_common_value = lhs_df[col].mode()[0] if col == lhs_column else rhs_df[col].mode()[0]
    
    mean_length = lhs_df[col].astype(str).str.len().mean() if col == lhs_column else rhs_df[col].astype(str).str.len().mean()
    min_length = lhs_df[col].astype(str).str.len().min() if col == lhs_column else rhs_df[col].astype(str).str.len().min()
    max_length = lhs_df[col].astype(str).str.len().max() if col == lhs_column else rhs_df[col].astype(str).str.len().max()
    
    summary_stats.loc[len(summary_stats)] = [col, null_values, distinct_values, non_distinct_values, most_common_value, mean_length, min_length, max_length]

# Display summary statistics
display.display(summary_stats)

# Generate detailed view with inferred patterns and data types
detailed_view = pd.DataFrame(columns=["Column", "Data Type", "Top Patterns", "Inferred Data Domain"])

for col in [lhs_column] + rhs_columns:
    data_type = lhs_df[col].dtype if col == lhs_column else rhs_df[col].dtype
    inferred_patterns = lhs_df[col].astype(str).str.extract(r'([A-Za-z]+)')[0].dropna().unique() if col == lhs_column else rhs_df[col].astype(str).str.extract(r'([A-Za-z]+)')[0].dropna().unique()
    inferred_data_domain = "Categorical" if data_type == 'object' else "Numerical"
    
    detailed_view.loc[len(detailed_view)] = [col, data_type, inferred_patterns, inferred_data_domain]

# Display detailed view
display.display(detailed_view)
# Out:
#                           Column  Null Values  Distinct Values  \
# 0                          BBTYP            0              780
# 1                        Variety            0             1450
# 2   Category name - Sub category            0             1421
# 3         Ingredient  Name in OS            0             1422
# 4          Option Set Long  Name            0             1429
# 5                   Sorter  Name            0             1459
# 6    Price Family code (tobacco)            0             1327
# 7          Item Name From Vendor            0             1245
# 8                 friendly size             0             1420
# 9                 Item Long Name            0             1398
# 10          Ingredient Long Name            0             1244
#
#     Non-Distinct Values    Most Common Value  Mean Length  Min Length  \
# 0                     8     Add scene teach.    16.799492           7
# 1                    15   Back ability fish.    16.928328           7
# 2                    44      Responsibility.    16.970648           8
# 3                    43       End line call.    16.952218           7
# 4                    36        Relationship.    16.870307           6
# 5                     6      Responsibility.    17.019795           7
# 6                   138      Responsibility.    16.849829           7
# 7                   220       Environmental.    17.107167           7
# 8                    45      Administration.    16.980205           8
# 9                    67  Address commercial.    16.772696           6
# 10                  221             Perform.    16.861433           6
#
#     Max Length
# 0           20
# 1           20
# 2           20
# 3           20
# 4           20
# 5           20
# 6           20
# 7           20
# 8           20
# 9           20
# 10          20
#                           Column Data Type  \
# 0                          BBTYP    object
# 1                        Variety    object
# 2   Category name - Sub category    object
# 3         Ingredient  Name in OS    object
# 4          Option Set Long  Name    object
# 5                   Sorter  Name    object
# 6    Price Family code (tobacco)    object
# 7          Item Name From Vendor    object
# 8                 friendly size     object
# 9                 Item Long Name    object
# 10          Ingredient Long Name    object
#
#                                          Top Patterns Inferred Data Domain
# 0   [Act, Degree, Strategy, Floor, Involve, If, Pa...          Categorical
# 1   [About, Prepare, Training, Series, Near, Live,...          Categorical
# 2   [Consider, Artist, Task, Participant, Affect, ...          Categorical
# 3   [Half, Blood, Woman, Sort, Hit, May, Crime, In...          Categorical
# 4   [Laugh, Job, Performance, Light, Join, Particu...          Categorical
# 5   [We, Through, Could, Rise, Able, Certain, Grow...          Categorical
# 6   [Sit, Seven, At, Seat, Station, Chance, Skin, ...          Categorical
# 7   [Beat, None, Key, Election, Dog, Analysis, Wor...          Categorical
# 8   [Make, Follow, Under, Movie, Physical, Enjoy, ...          Categorical
# 9   [Finish, By, Though, Environmental, Able, Repr...          Categorical
# 10  [American, Senior, Effect, Interesting, Apply,...          Categorical
